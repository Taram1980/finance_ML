# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier

#from matplotlib.colors import ListedColormap
#from sklearn import datasets, metrics, tree 
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from subprocess import call
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.tree import export_graphviz
from sklearn.metrics import roc_auc_score, confusion_matrix

import xgboost as xgb

import seaborn as sns

from termcolor import colored



#from sklearn.ensemble import VotingClassifier
#from catboost import CatBoostClassifier
#import xgboost

from matplotlib.colors import ListedColormap
# %pylab inline

pd.options.mode.chained_assignment = None  # default='warn'
# Out:
# Populating the interactive namespace from numpy and matplotlib
# C:\Users\afecn\anaconda3.1\lib\site-packages\IPython\core\magics\pylab.py:160: UserWarning: pylab import has clobbered these variables: ['all', 'matrix']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
feature = [
 'Cl/min_day',
 'Cl/max_day',
 'max_day-min_day',
 'ADX_5',
 'ADX_14',
 'ADX_28',
 'ADXR_5',
 'ADXR_14',
 'ADXR_28',
 'APO_5',
 'APO_14',
 'APO_28',
 'AROONOSC_5',
 'AROONOSC_14',
 'AROONOSC_28',
 'BOP_5',
 'BOP_14',
 'BOP_28',
 'CCI_5',
 'CCI_14',
 'CCI_28',
 'CMO_5',
 'CMO_14',
 'CMO_28',
 'DX_5',
 'DX_14',
 'DX_28',
 'MFI_5',
 'MFI_14',
 'MFI_28',
 'MINUS_DI_5',
 'MINUS_DI_14',
 'MINUS_DI_28',
 'MINUS_DM_5',
 'MINUS_DM_14',
 'MINUS_DM_28',
 'MOM_5',
 'MOM_14',
 'MOM_28',
 'PLUS_DI_5',
 'PLUS_DI_14',
 'PLUS_DI_28',
 'PLUS_DM_5',
 'PLUS_DM_14',
 'PLUS_DM_28',
 'PPO_5',
 'PPO_14',
 'PPO_28',
 'ROC_5',
 'ROC_14',
 'ROC_28',
 'ROCP_5',
 'ROCP_14',
 'ROCP_28',
 'ROCR_5',
 'ROCR_14',
 'ROCR_28',
 'ROCR100_5',
 'ROCR100_14',
 'ROCR100_28',
 'RSI_5',
 'RSI_14',
 'RSI_28',
 'TRIX_5',
 'TRIX_14',
 'TRIX_28',
 'ULTOSC_5',
 'ULTOSC_14',
 'ULTOSC_28',
 'WILLR_5',
 'WILLR_14',
 'WILLR_28',
 'HT_DCPERIOD_5',
 'HT_DCPERIOD_14',
 'HT_DCPERIOD_28',
 'HT_DCPHASE_5',
 'HT_DCPHASE_14',
 'HT_DCPHASE_28',
 'HT_TRENDMODE_5',
 'HT_TRENDMODE_14',
 'HT_TRENDMODE_28',
 'DEMA_5',
 'DEMA_14',
 'DEMA_28',
 'EMA_5',
 'EMA_14',
 'EMA_28',
 'HT_TRENDLINE_5',
 'HT_TRENDLINE_14',
 'HT_TRENDLINE_28',
 'KAMA_5',
 'KAMA_14',
 'KAMA_28',
 'MA_5',
 'MA_14',
 'MA_28',
 'MIDPOINT_5',
 'MIDPOINT_14',
 'MIDPOINT_28',
 'MIDPRICE_5',
 'MIDPRICE_14',
 'MIDPRICE_28',
 'SMA_5',
 'SMA_14',
 'SMA_28',
 'T3_5',
 'T3_14',
 'T3_28',
 'TEMA_5',
 'TEMA_14',
 'TEMA_28',
 'TRIMA_5',
 'TRIMA_14',
 'TRIMA_28',
 'WMA_5',
 'WMA_14',
 'WMA_28',
 'ATR_5',
 'ATR_14',
 'ATR_28',
 'NATR_5',
 'NATR_14',
 'NATR_28',
 'TRANGE_5',
 'TRANGE_14',
 'TRANGE_28',
 'AD_5',
 'AD_14',
 'AD_28',
 'ADOSC_5',
 'ADOSC_14',
 'ADOSC_28',
 'OBV_5',
 'OBV_14',
 'OBV_28',
 'AROON_aroondown',
 'AROON_aroonup',
 'MACD_macd',
 'MACD_macdsignal',
 'MACD_macdhist',
 'MACDEXT_macd',
 'MACDEXT_macdsignal',
 'MACDEXT_macdhist',
 'MACDFIX_macd',
 'MACDFIX_macdsignal',
 'MACDFIX_macdhist',
 'STOCH_slowk',
 'STOCH_slowd',
 'STOCHF_fastk',
 'STOCHF_fastd',
 'STOCHRSI_fastk',
 'STOCHRSI_fastd',
 'HT_PHASOR_inphase',
 'HT_PHASOR_quadrature',
 'HT_SINE_sine',
 'HT_SINE_leadsine',
 'BBANDS_upperband',
 'BBANDS_middleband',
 'BBANDS_lowerband',
 'MAMA_mama',
 'MAMA_fama',
 'Min10',
 'Min1000',
 'Min10_1300',
 'Min10_1000'
]

# %%
#разбивка датасетов
def dating(year):
    X_all_16 = X_all[                         (data[column] != year)]
    X_all_19 = X_all[                         (data[column] ==  year)]
    y_all_16 = y_all[                         (data[column] != year)]
    y_all_19 = y_all[                         (data[column] ==  year)]
    X_train, X_test, y_train, y_test = train_test_split(
    X_all_16,
    y_all_16, 
    test_size = 0.3,
    random_state = 1)
    return X_train, X_test, y_train, y_test, X_all_16, y_all_16, X_all_19, y_all_19 

#прогнозы
def result_(varP, varM):
    tablep = pd.pivot_table(
    matrix_year[(matrix_year['2proba']>=varP) &(matrix_year[column] >200)],                      
            margins=True, index=all, values = ['Target_','Profit_carrent'],
            aggfunc=['count', 'mean']).round(2)
    
    tablem = pd.pivot_table(
    matrix_year[(matrix_year['1proba']>varM) &(matrix_year[column] >200)],                      
            margins=True, index=all, values = ['Target_','Profit_carrent'],
            aggfunc=['count', 'mean']).round(2)
    table = pd.concat([tablep, tablem], axis=1)
#    table.columns = ['Profit%_c','Count','Profit%','Profit+-']
#    table.pop('Profit%_c')
    return table

def feat_():
    tablef = pd.pivot_table(
    matrix_year[(matrix_year[column] >200)],                      
            margins=True, index=all, values = 'f_' + X_train.columns,        
            aggfunc=['mean']).round(2)
    return tablef

# %%
# %%time

# #TA+4block
#TA_block4   = pd.read_csv('E:/Host/Data/Database/10min/TA_block4.csv',   parse_dates=['Date', 'Time'])
# #создать target
#profit_TIME = pd.read_csv('E:/Host/Data/Database/10min/profit_TIME.csv', parse_dates=['Date', 'Time'])

#TA+4block
TA_block4   = pd.read_csv('TA_block4.csv', parse_dates=['Date', 'Time'])
#создать target
profit_TIME = pd.read_csv('profit_TIME.csv', parse_dates=['Date', 'Time'])
# Out:
# Wall time: 21.5 s

# %%
Target_list = ['ProftLaBa', 'Proft1000', 'Proft1300', 'Proft1830', 'Profi_GEP', 'Pro_Morni',]
feature =  ['Min10',
#  'Min1000',
#  'Min10_1300',
#  'Min10_1000',
#  'Cl/min_day',
#  'Cl/max_day',
#  'max_day-min_day',


           ]

# %%
# к TA_block4 добавлаям профиты по отсечке
def shose(from_):
#     display(TA_block4   .shape)
#     display(profit_TIME.shape)
#    display(TA_block4[TA_block4['Time'] == from_].shape)
#    display(profit_TIME[profit_TIME['Time'] == from_].shape)

    df = pd.merge(TA_block4[TA_block4['Time'] == from_], profit_TIME[profit_TIME['Time'] == from_], on = ['Date', 'Time', 'Symbol'], how='inner')

#    display(df.shape)
    df.drop_duplicates(['Date', 'Time', 'Symbol'], inplace = True)
#    display(df.shape)
    df.dropna(inplace = True)
#    display(df)
    return(df)

# %%
fi1
# Out:
#                  0      1
# 0            Min10  0.196
# 1          Min1000  0.132
# 2       Min10_1300  0.087
# 3       Min10_1000  0.070
# 4       Cl/min_day  0.198
# 5       Cl/max_day  0.151
# 6  max_day-min_day  0.166

# %%
# %%time

# сама модель БЕЗ ВЫБОРА ФИЧЕЙ 

n_ = 2

feat_importances = pd.DataFrame()
matrix   = pd.DataFrame()
matrix_year_nul = pd.DataFrame()
matrix_2 = pd.DataFrame()
matrix_100 = pd.DataFrame()
matrix_2_100  = pd.DataFrame()
matrix_year   = pd.DataFrame()

matrix_year_h = pd.DataFrame()

forecast = pd.DataFrame()

for from_ in ['12:45:00']:
    data = shose(from_)
    data['Year'] = data ['Date'].dt.year
    column = 'Year'
    for Target in ['Proft1000']:
   #      data['Target_'] = np.where(data['Proft1300']>0.0, np.where(data['Proft1830']>-1,1,0),0)
        data['Target_'] = np.where(data[Target]>0.0, 1, 0)
        data['Profit_carrent'] = data[Target]
        for itera_2 in [0.4]:
            for itera_1 in [25]:
                for itera in [2]:
                    for year in [2010,2011,2012,2013,2014,2015,2016,2017]:

  #                      print(str(from_) + ' ' + str(Target) + ' ' + str(year) + ' ' + str(itera) + ' ' + str(itera_1) + ' ' + str(itera_2))

  #                      print('****')
                    



                        X_all = data[feature] 
                        y_all = data['Target_']    
                        X_train = X_all[(data[column] <  year)&(data[column] >= 2009)]
                        X_test  = X_all[data[column]  >= year]
                        y_train = y_all[(data[column] <  year)&(data[column] >=  2009)]
                        y_test  = y_all[data[column]  >= year]

#                        display(X_train.shape, X_test.shape, y_train.shape, y_test.shape)


                        model = GradientBoostingClassifier(n_estimators=itera_1, max_depth = itera, random_state=1)
                        model.fit(X_train, y_train)
                        estimator = model.estimators_[0]

                        fi = pd.Series(model.feature_importances_).round(3)
                        fi1 = pd.concat([pd.Series(feature), fi], axis = 1)
    #                   display(fi1)
                        feat_importances = pd.concat([feat_importances, fi1], axis = 1)
    #                   display(feat_importances)


                        predictions_X_train     = model.predict(X_train)
                        predictions_X_test      = model.predict(X_test)
                        predictions_X_all       = model.predict(X_all)
                        predictions_proba_X_all = model.predict_proba(X_all)

                                    #Добавялем пробы в data.copy
                                    #data_copy = data.copy()
                        data['y_all'] =  y_all
                        data['predictions_X_all']  = predictions_X_all
                        for number_ in range(1, n_+1, 1):
                            data[str(number_)+'proba'] = predictions_proba_X_all[:, number_-1]


                        matrix_2018 = data[data[column]   == year]
                        matrix_2018 = matrix_2018.assign(itera_2 = str(itera_2),
                                                         Target  = str(Target),
                                                         itera_1   = str(itera_1),
                                                         itera   = str(itera),
                                                         from_   = str(from_)
                                                        )
                      #vertical
                        matrix_2018_null = data[data[column]   == year]
                        matrix_2018_null = matrix_2018_null.assign(itera_2 = str(itera_2),
                                                         Target  = str(Target),
                                                         itera_1   = str(itera_1),
                                                         itera   = str(itera),
                                                         from_   = str(from_)
                                                        )
                        matrix_year_nul  = matrix_year_nul.append(matrix_2018_null, ignore_index=True)
                        #vertical
                        
#                        display(matrix_2018[['Target','from_', 'Date', 'Time', 'Profit_carrent', 'Year']].head(20))
                        matrix_year   = matrix_year.append(matrix_2018, ignore_index=True)
                    #vertical
                    matrix_year_h = pd.concat([matrix_year_h, matrix_year_nul], axis=1)
                    matrix_year_nul = pd.DataFrame()

                    #vertical
                
#print(result_(0.55,0.5))
# Out:
# Wall time: 1.65 s

# %%
display(matrix10min.shape)
display(matrix15min.shape)
mer = pd.merge(matrix10min, matrix15min, on = ['Symbol', 'Date', 'Hour'], how = 'inner')
display(mer.shape)
# Out:
# (11988, 209)
# (11962, 209)
# (11956, 415)

# %%
mer[['Symbol', 'Date', 'Hour', 'Time_x', 'Time_y', 'Min10_x', 'Min10_y', 'Target__x', 'Target__y', 'Proft1000_x', 'Proft1000_y', '2proba_x', '2proba_y']]
# Out:
#       Symbol       Date  Hour              Time_x              Time_y  \
# 0       GAZP 2010-01-11    12 2020-09-23 12:50:00 2020-09-23 12:45:00
# 1       GAZP 2010-01-12    12 2020-09-23 12:50:00 2020-09-23 12:45:00
# 2       GAZP 2010-01-13    12 2020-09-23 12:50:00 2020-09-23 12:45:00
# 3       GAZP 2010-01-14    12 2020-09-23 12:50:00 2020-09-23 12:45:00
# 4       GAZP 2010-01-15    12 2020-09-23 12:50:00 2020-09-23 12:45:00
# ...      ...        ...   ...                 ...                 ...
# 11951   VTBR 2017-12-25    12 2020-09-23 12:50:00 2020-09-23 12:45:00
# 11952   VTBR 2017-12-26    12 2020-09-23 12:50:00 2020-09-23 12:45:00
# 11953   VTBR 2017-12-27    12 2020-09-23 12:50:00 2020-09-23 12:45:00
# 11954   VTBR 2017-12-28    12 2020-09-23 12:50:00 2020-09-23 12:45:00
# 11955   VTBR 2017-12-29    12 2020-09-23 12:50:00 2020-09-23 12:45:00
#
#         Min10_x   Min10_y  Target__x  Target__y  Proft1000_x  Proft1000_y  \
# 0      6.911684  7.264721          1          1     0.256542     0.102623
# 1     -1.067378 -0.879181          0          0    -1.493853    -1.649459
# 2     -0.480067 -0.563088          1          1     0.199245     0.094375
# 3      0.977543  0.950873          0          0    -0.627943    -0.544222
# 4      0.467167  0.298691          0          0    -2.037618    -1.906998
# ...         ...       ...        ...        ...          ...          ...
# 11951  0.021327  0.751884          1          1     0.874200     0.895525
# 11952 -0.106360 -0.718816          0          0    -0.681431    -0.745313
# 11953  1.981253  2.177159          0          0    -0.543138    -0.793812
# 11954 -1.563160 -1.791359          1          1     0.278970     0.300429
# 11955  0.256355 -0.063884          1          1     1.235883     1.512892
#
#        2proba_x  2proba_y
# 0      0.623116  0.650022
# 1      0.560800  0.550043
# 2      0.560800  0.550043
# 3      0.545193  0.538596
# 4      0.545193  0.542564
# ...         ...       ...
# 11951  0.505877  0.506656
# 11952  0.527019  0.518926
# 11953  0.572505  0.542190
# 11954  0.521531  0.518926
# 11955  0.512321  0.518073
#
# [11956 rows x 13 columns]

# %%
mer[mer['2proba_x'] >=0.55]['Proft1000_x'].agg(['mean', 'count'])
# Out:
# mean        0.180048
# count    1131.000000
# Name: Proft1000_x, dtype: float64

# %%
mer[mer['2proba_y'] >=0.55]['Proft1000_y'].agg(['mean', 'count'])
# Out:
# mean        0.098354
# count    1090.000000
# Name: Proft1000_y, dtype: float64

# %%
matrix15min['Hour'] = matrix15min['Time'].dt.hour
#matrix10min['Time'].dt.minute
# Out:
# 0        50
# 1        50
# 2        50
# 3        50
# 4        50
#          ..
# 11983    50
# 11984    50
# 11985    50
# 11986    50
# 11987    50
# Name: Time, Length: 11988, dtype: int64

# %%
list(matrix15min)
matrix15min['2proba'].mean()
# Out:
# 0.5202974570397279

# %%
list(matrix_year)
matrix10min
# Out:
#        Unnamed: 0_x       Date       Open       High        Low    Close_x  \
# 0             46373 2010-01-11  194.82000  194.92000  194.57000  194.90000
# 1             46423 2010-01-12  192.51000  192.89000  192.50000  192.79000
# 2             46473 2010-01-13  190.59000  190.94000  190.59000  190.72000
# 3             46523 2010-01-14  190.90000  191.19000  190.89000  191.10000
# 4             46573 2010-01-15  191.58000  191.69000  191.30000  191.40000
# ...             ...        ...        ...        ...        ...        ...
# 11983       1080375 2017-12-25    0.04699    0.04699    0.04688    0.04690
# 11984       1080429 2017-12-26    0.04692    0.04698    0.04690    0.04696
# 11985       1080483 2017-12-27    0.04795    0.04800    0.04785    0.04787
# 11986       1080537 2017-12-28    0.04663    0.04663    0.04641    0.04660
# 11987       1080591 2017-12-29    0.04698    0.04711    0.04691    0.04693
#
#              Volume Symbol                Time       Cl_1    Cl_Last  Long  \
# 0      2.054965e+08   GAZP 2020-09-23 12:50:00  192.98000  194.50000    15
# 1      7.479751e+07   GAZP 2020-09-23 12:50:00  195.40000  191.80000    15
# 2      3.592650e+07   GAZP 2020-09-23 12:50:00  189.91000  189.30000    15
# 3      2.470835e+08   GAZP 2020-09-23 12:50:00  191.10000  190.83000    15
# 4      1.610286e+08   GAZP 2020-09-23 12:50:00  189.90000  187.86000    15
# ...             ...    ...                 ...        ...        ...   ...
# 11983  2.965083e+06   VTBR 2020-09-23 12:50:00    0.04689    0.04730    19
# 11984  4.648379e+06   VTBR 2020-09-23 12:50:00    0.04729    0.04685    19
# 11985  1.549109e+07   VTBR 2020-09-23 12:50:00    0.04680    0.04745    19
# 11986  2.568116e+07   VTBR 2020-09-23 12:50:00    0.04751    0.04696    19
# 11987  1.154220e+07   VTBR 2020-09-23 12:50:00    0.04700    0.04732    19
#
#        Short    min_day    max_day  Cl/min_day  Cl/max_day  max_day-min_day  \
# 0         36  191.00000  194.97000    2.041885   -0.035903         2.036942
# 1         36  191.37000  195.80000    0.742018   -1.537283         2.297837
# 2         36  189.24000  191.86000    0.782076   -0.594183         1.373742
# 3         36  190.09000  191.33000    0.531327   -0.120211         0.648875
# 4         36  189.70000  192.10000    0.896152   -0.364394         1.253918
# ...      ...        ...        ...         ...         ...              ...
# 11983     36    0.04630    0.04719    1.295896   -0.614537         1.897655
# 11984     36    0.04671    0.04738    0.535217   -0.886450         1.426746
# 11985     36    0.04650    0.04905    2.946237   -2.405708         5.326927
# 11986     36    0.04641    0.04779    0.409395   -2.490061         2.961373
# 11987     36    0.04657    0.04723    0.773030   -0.635189         1.406350
#
#            ADX_5     ADX_14     ADX_28     ADXR_5    ADXR_14    ADXR_28  \
# 0      78.367791  60.018668  36.590152  77.317289  44.166085  25.787739
# 1      70.325658  44.571795  31.877666  74.105093  37.028220  39.696599
# 2      33.895309  25.819485  27.426107  34.115317  32.373962  29.436289
# 3      26.891517  12.965917  10.853493  20.437797  18.445642  14.481046
# 4      29.231435  15.782230   9.151564  38.312556  15.612755   8.342386
# ...          ...        ...        ...        ...        ...        ...
# 11983  12.853112  18.678372  20.907718  13.798373  21.022152  22.958108
# 11984  27.559683  13.246595   9.822735  24.745564  15.610958  11.120903
# 11985  39.072540  35.833398  21.398594  52.632486  28.604059  14.926932
# 11986  73.428293  30.655537  14.851240  69.782615  19.245516  13.928864
# 11987  30.574302  13.433304  13.270241  31.076301  15.456821  17.825388
#
#           APO_5    APO_14    APO_28  AROONOSC_5  AROONOSC_14  AROONOSC_28  \
# 0      5.283769  4.788626  0.437445        80.0    92.857143    78.571429
# 1     -1.816231 -0.968516 -0.103626       -60.0   -78.571429   -82.142857
# 2      0.040692 -0.376593 -0.044121        20.0    71.428571   -46.428571
# 3      0.409000  0.335000 -0.041786       100.0   -28.571429   -39.285714
# 4      0.724615  0.466044  0.099313       -60.0    57.142857    67.857143
# ...         ...       ...       ...         ...          ...          ...
# 11983  0.000079  0.000070  0.000021       -40.0     7.142857   -10.714286
# 11984 -0.000044 -0.000028  0.000008      -100.0    50.000000   -14.285714
# 11985  0.000632  0.000597  0.000042       -80.0    50.000000    32.142857
# 11986 -0.000646 -0.000250 -0.000030      -100.0  -100.000000   -92.857143
# 11987 -0.000024  0.000043  0.000017        40.0   -28.571429    64.285714
#
#           BOP_5    BOP_14    BOP_28       CCI_5      CCI_14      CCI_28  \
# 0      0.228571  0.228571  0.228571   73.411249  173.760424   73.479250
# 1      0.717949  0.717949  0.717949  117.469880  -50.177765  -94.734972
# 2      0.371429  0.371429  0.371429  -47.545486   45.978368  -16.354868
# 3      0.666667  0.666667  0.666667  109.631148  112.679266   78.308896
# 4     -0.461538 -0.461538 -0.461538   15.710383   44.593013   88.847315
# ...         ...       ...       ...         ...         ...         ...
# 11983 -0.818182 -0.818182 -0.818182   -2.109705   55.477855   57.861126
# 11984  0.500000  0.500000  0.500000  -81.513828  -87.437005  -67.875828
# 11985 -0.533333 -0.533333 -0.533333  -85.464334  -23.163674   43.864082
# 11986 -0.136364 -0.136364 -0.136364 -123.836127  -96.422601 -148.735090
# 11987 -0.250000 -0.250000 -0.250000  135.135135   34.003350   76.739223
#
#            CMO_5     CMO_14     CMO_28       DX_5      DX_14      DX_28  \
# 0      78.723715  74.811813  65.635007  73.786116  77.447626  68.888650
# 1      -3.182158 -22.378914  -5.087895  50.168262  53.112025  23.637465
# 2      -0.545421  -5.547646  -8.731740  34.312205   4.299042  10.133533
# 3      42.389362  14.716301   5.880102  48.145314  14.000327   4.584818
# 4       4.588458  13.481730   9.079585  15.507799   4.423088   3.218227
# ...          ...        ...        ...        ...        ...        ...
# 11983  -2.536096   7.429088  11.716757   1.607426  12.830701  15.946839
# 11984 -21.945326  -7.234238   1.028118  41.989966  16.276722   5.312918
# 11985 -33.767700   8.396261  14.540961  24.794521  17.577722  21.307425
# 11986 -77.339147 -53.843592 -31.179818  82.306420  59.006442  35.630512
# 11987  10.693703   5.572085   2.085085  25.274189   3.637857   3.312941
#
#               MFI_5     MFI_14     MFI_28  MINUS_DI_5  MINUS_DI_14  \
# 0      8.649981e+01  78.233479  77.090673    7.252138     7.062262
# 1      4.671364e+01  29.362588  35.157127   38.358212    37.600784
# 2      5.829068e+01  71.738710  61.333568   13.591184    20.697971
# 3      1.000000e+02  78.792689  60.930727    9.130273    17.730627
# 4      9.031947e+00  63.590164  62.245980   20.269737    20.053024
# ...             ...        ...        ...         ...          ...
# 11983  9.051858e+01  61.258697  61.243110   17.123160    19.511843
# 11984  1.563340e+01  34.271851  36.201037   27.265299    25.224738
# 11985  1.366027e-12  65.486553  61.035838   28.259291    20.864211
# 11986  1.869243e+01  12.586651  27.755819   42.084927    37.802445
# 11987  7.277446e+01  49.524734  60.517426   15.922760    20.541373
#
#        MINUS_DI_28  MINUS_DM_5  MINUS_DM_14  ...  MACDFIX_macd  \
# 0         9.571080    0.195276     0.741025  ...      2.765748
# 1        31.184291    1.250439     3.379648  ...     -0.664417
# 2        24.634765    0.370258     1.712011  ...     -0.188416
# 3        20.356517    0.183618     1.273556  ...      0.125795
# 4        20.884990    0.556894     1.564197  ...      0.292050
# ...            ...         ...          ...  ...           ...
# 11983    19.228120    0.000136     0.000554  ...      0.000074
# 11984    23.045475    0.000171     0.000473  ...      0.000003
# 11985    19.860093    0.000455     0.000853  ...      0.000312
# 11986    32.746501    0.000468     0.001143  ...     -0.000264
# 11987    22.290686    0.000141     0.000526  ...      0.000028
#
#        MACDFIX_macdsignal  MACDFIX_macdhist  STOCH_slowk  STOCH_slowd  \
# 0                2.750352          0.015396    94.076901    91.670162
# 1               -0.518906         -0.145512    66.935540    44.123071
# 2               -0.269354          0.080938    19.078144    32.042067
# 3                0.061472          0.064323    77.904762    67.349635
# 4                0.242809          0.049242    58.213963    48.072104
# ...                   ...               ...          ...          ...
# 11983            0.000088         -0.000014    46.384480    55.915439
# 11984            0.000023         -0.000020    11.391053    17.054353
# 11985            0.000329         -0.000016    14.662005    19.302835
# 11986           -0.000199         -0.000065    27.980620    21.272019
# 11987            0.000040         -0.000012    47.854107    39.273695
#
#        STOCHF_fastk  STOCHF_fastd  STOCHRSI_fastk  STOCHRSI_fastd  \
# 0         94.444444     94.076901      100.000000    9.429988e+01
# 1         92.810458     66.935540      100.000000    6.666667e+01
# 2         14.285714     19.078144       15.356982    1.550690e+01
# 3         88.000000     77.904762      100.000000    1.000000e+02
# 4         61.904762     58.213963       21.188108    2.933725e+01
# ...             ...           ...             ...             ...
# 11983     37.037037     46.384480       14.573162    3.230907e+01
# 11984     24.000000     11.391053       19.321088    6.440363e+00
# 11985      6.410256     14.662005        0.000000   -5.968559e-13
# 11986     42.222222     27.980620       49.406276    3.481998e+01
# 11987     47.058824     47.854107       93.297683    6.443256e+01
#
#        HT_PHASOR_inphase  HT_PHASOR_quadrature  HT_SINE_sine  \
# 0               0.078045              0.268745     -0.428403
# 1              -0.880937              0.257357     -0.072513
# 2               0.289171              0.120768      0.922631
# 3              -0.072981              0.240629     -0.499094
# 4               0.288189             -0.685884     -0.568902
# ...                  ...                   ...           ...
# 11983          -0.000010              0.000037     -0.831909
# 11984           0.000080             -0.000071      0.089808
# 11985           0.000127             -0.000723     -0.535339
# 11986          -0.000297              0.000059      0.102037
# 11987          -0.000146              0.000307     -0.794107
#
#        HT_SINE_leadsine  BBANDS_upperband  BBANDS_middleband  \
# 0             -0.941860          0.208782          -0.211390
# 1              0.653971          0.042748          -0.187769
# 2              0.379680          0.457165           0.093331
# 3             -0.965655          0.063905          -0.133961
# 4             -0.983803          0.170803           0.015674
# ...                 ...               ...                ...
# 11983         -0.195866          0.195613           0.046908
# 11984         -0.640746          0.440151           0.102215
# 11985         -0.975791          1.499586           0.568206
# 11986          0.775567          0.305831           0.072961
# 11987         -0.991282          0.121590          -0.136373
#
#        BBANDS_lowerband  MAMA_mama  MAMA_fama  Unnamed: 0_y    Close_y  \
# 0             -0.631563  -0.330976  -2.397886           245  192.98000
# 1             -0.418286  -0.048394   0.329501           246  195.40000
# 2             -0.270504   0.052901   0.100825           247  189.91000
# 3             -0.331827  -0.219424  -0.370133           248  191.10000
# 4             -0.139455   0.007863  -0.312869           249  189.90000
# ...                 ...        ...        ...           ...        ...
# 11983         -0.101796  -0.027609  -0.178301          2237    0.04678
# 11984         -0.235721   0.162460   0.229671          2238    0.04731
# 11985         -0.363175   0.386576  -1.162061          2239    0.04664
# 11986         -0.159908   0.523878   1.494530          2240    0.04761
# 11987         -0.394336  -0.134509  -0.123854          2241    0.04673
#
#        Close10:50:00  Close11:50:00  Close12:50:00  Close13:50:00  \
# 0          193.64000      193.94000      194.90000      195.90000
# 1          194.45000      192.93000      192.79000      192.87000
# 2          189.87000      190.40000      190.72000      190.10000
# 3          191.02000      190.70000      191.10000      190.75000
# 4          190.06000      191.62000      191.40000      189.75000
# ...              ...            ...            ...            ...
# 11983        0.04687        0.04691        0.04690        0.04693
# 11984        0.04691        0.04716        0.04696        0.04685
# 11985        0.04710        0.04854        0.04787        0.04780
# 11986        0.04756        0.04697        0.04660        0.04651
# 11987        0.04697        0.04685        0.04693        0.04694
#
#        Close14:50:00  Close15:50:00  Close16:50:00  Closelast_bar  ProftLaBa  \
# 0          195.63000      195.52000      195.80000      194.87000  -0.015393
# 1          192.00000      191.30000      191.33000      191.64000  -0.596504
# 2          190.00000      190.93000      190.74000      189.25000  -0.770763
# 3          190.80000      190.80000      189.23000      190.51000  -0.308739
# 4          189.99000      189.04000      189.49000      187.90000  -1.828631
# ...              ...            ...            ...            ...        ...
# 11983        0.04684        0.04689        0.04687        0.04701   0.234542
# 11984        0.04689        0.04691        0.04697        0.04694  -0.042589
# 11985        0.04803        0.04744        0.04785        0.04734  -1.107165
# 11986        0.04647        0.04657        0.04669        0.04681   0.450644
# 11987        0.04704        0.04704        0.04706        0.04720   0.575325
#
#        Proft1000  Proft1300  Proft1830  Profi_GEP  Pro_Morni     Min10  \
# 0       0.256542  -1.082606  -1.672653   0.271976  -1.335722  6.911684
# 1      -1.493853  -1.073707  -1.836195  -0.902734   0.426518 -1.067378
# 2       0.199245   0.199245  -0.110109   0.977543   0.000000 -0.480067
# 3      -0.627943   0.156986  -1.674516  -0.320193   0.789889  0.977543
# 4      -2.037618  -1.562173  -0.778474  -0.212879   0.485333  0.467167
# ...          ...        ...        ...        ...        ...       ...
# 11983   0.874200   0.127932   0.085288   0.638162  -0.739801  0.021327
# 11984  -0.681431   1.937819   0.809199  -0.639114   2.637221 -0.106360
# 11985  -0.543138  -2.653019  -2.214330   0.570342  -2.121403  1.981253
# 11986   0.278970   0.708155   1.287554  -0.170904   0.427991 -1.563160
# 11987   1.235883   2.407841   4.879608   0.656780   1.157651  0.256355
#
#         Min1000  Min10_1300  Min10_1000  Year  Target_  Profit_carrent  y_all  \
# 0      0.994922    6.935148    6.218323  2010        1        0.256542      1
# 1     -1.335722   -1.082606   -0.098456  2010        0       -1.493853      0
# 2      0.426518   -1.073707   -2.395087  2010        1        0.199245      1
# 3      0.000000    0.199245    0.626613  2010        0       -0.627943      0
# 4      0.789889    0.156986    0.156986  2010        0       -2.037618      0
# ...         ...         ...         ...   ...      ...             ...    ...
# 11983  0.256520    1.361573    3.031634  2017        1        0.874200      1
# 11984 -0.739801    0.127932    0.384780  2017        0       -0.681431      0
# 11985  2.637221    1.937819    1.183682  2017        0       -0.543138      0
# 11986 -2.121403   -2.653019   -0.085763  2017        1        0.278970      1
# 11987  0.427991    0.708155   -1.428271  2017        1        1.235883      1
#
#        predictions_X_all    1proba    2proba  itera_2     Target  itera_1  \
# 0                      1  0.376884  0.623116      0.4  Proft1000       25
# 1                      1  0.439200  0.560800      0.4  Proft1000       25
# 2                      1  0.439200  0.560800      0.4  Proft1000       25
# 3                      1  0.454807  0.545193      0.4  Proft1000       25
# 4                      1  0.454807  0.545193      0.4  Proft1000       25
# ...                  ...       ...       ...      ...        ...      ...
# 11983                  1  0.494123  0.505877      0.4  Proft1000       25
# 11984                  1  0.472981  0.527019      0.4  Proft1000       25
# 11985                  1  0.427495  0.572505      0.4  Proft1000       25
# 11986                  1  0.478469  0.521531      0.4  Proft1000       25
# 11987                  1  0.487679  0.512321      0.4  Proft1000       25
#
#        itera     from_
# 0          2  12:50:00
# 1          2  12:50:00
# 2          2  12:50:00
# 3          2  12:50:00
# 4          2  12:50:00
# ...      ...       ...
# 11983      2  12:50:00
# 11984      2  12:50:00
# 11985      2  12:50:00
# 11986      2  12:50:00
# 11987      2  12:50:00
#
# [11988 rows x 208 columns]

# %%
matrix_year[['Date',
 'Open',
 'High',
 'Low',
 'Close_x',
 'Volume',
 'Symbol',
 'Time',
 'Cl_1',
 'Cl_Last',
 'Long',
 'Short',
 'min_day',
 'max_day',
 'Cl/min_day',
 'Cl/max_day',
 'max_day-min_day',
  'Close_y',
 'Close10:50:00',
 'Close11:50:00',
 'Close12:50:00',
 'Close13:50:00',
 'Close14:50:00',
 'Close15:50:00',
 'Close16:50:00',
 'Closelast_bar',
 'ProftLaBa',
 'Proft1000',
 'Proft1300',
 'Proft1830',
 'Profi_GEP',
 'Pro_Morni',
 'Min10',
 'Min1000',
 'Min10_1300',
 'Min10_1000',
 'Year',
 'Target_',
 'Profit_carrent',
 'y_all',
 'predictions_X_all',
 '1proba',
 '2proba',
 'itera_2',
 'Target',
 'itera_1',
 'itera',
 'from_',
 'date_time']].to_excel('test_profita.xlsx')

# %%
matrix_year['date_time'] = pd.to_datetime(matrix_year['Date'].astype(str) + " " + matrix_year['Time'].dt.time.astype(str)) # привести в порядок и создать новый столбец

# %%
# Out:
#                                  count                   mean          \
#                         Profit_carrent Target_ Profit_carrent Target_
# Target    Year from_
# All                               1100    1100           0.10    0.54
# Proft1000 2010 12:45:00            669     669           0.13    0.52
#           2011 12:45:00            175     175          -0.03    0.56
#           2012 12:45:00             91      91          -0.28    0.47
#           2013 12:45:00              6       6          -1.36    0.17
#           2014 12:45:00             23      23          -0.03    0.48
#           2015 12:45:00             81      81           0.46    0.65
#           2016 12:45:00             27      27           0.18    0.59
#           2017 12:45:00             18      18           1.10    0.89
#           2018 12:45:00             10      10           0.34    0.50
#
#                                  count                   mean
#                         Profit_carrent Target_ Profit_carrent Target_
# Target    Year from_
# All                               22.0    22.0          -0.28    0.41
# Proft1000 2010 12:45:00            4.0     4.0          -0.20    0.50
#           2011 12:45:00            9.0     9.0          -0.27    0.44
#           2012 12:45:00            NaN     NaN            NaN     NaN
#           2013 12:45:00            NaN     NaN            NaN     NaN
#           2014 12:45:00            5.0     5.0          -0.58    0.20
#           2015 12:45:00            1.0     1.0           0.19    1.00
#           2016 12:45:00            2.0     2.0          -0.58    0.00
#           2017 12:45:00            NaN     NaN            NaN     NaN
#           2018 12:45:00            1.0     1.0           0.86    1.00

# %%
pd.options.display.max_rows=2000
all = ['Target', 'Year', 'from_'] 
result_(0.55,0.55)
# Out:
#                                  count                   mean          \
#                         Profit_carrent Target_ Profit_carrent Target_
# Target    Year from_
# All                               1226    1226           0.20    0.57
# Proft1000 2010 12:50:00            609     609           0.16    0.55
#           2011 12:50:00            195     195          -0.01    0.57
#           2012 12:50:00             32      32           0.19    0.56
#           2013 12:50:00             46      46           0.03    0.48
#           2014 12:50:00             43      43           0.77    0.67
#           2015 12:50:00             71      71           0.32    0.66
#           2016 12:50:00             95      95           0.33    0.60
#           2017 12:50:00             41      41           0.35    0.63
#           2018 12:50:00             94      94           0.41    0.64
#
#                                  count                   mean
#                         Profit_carrent Target_ Profit_carrent Target_
# Target    Year from_
# All                               14.0    14.0           0.47    0.64
# Proft1000 2010 12:50:00            NaN     NaN            NaN     NaN
#           2011 12:50:00            3.0     3.0          -1.20    0.33
#           2012 12:50:00            NaN     NaN            NaN     NaN
#           2013 12:50:00            NaN     NaN            NaN     NaN
#           2014 12:50:00            3.0     3.0          -1.29    0.33
#           2015 12:50:00            1.0     1.0           0.04    1.00
#           2016 12:50:00            1.0     1.0           0.04    1.00
#           2017 12:50:00            NaN     NaN            NaN     NaN
#           2018 12:50:00            6.0     6.0           2.32    0.83

# %%
#пьяное пиво 2


pivo1 = pd.pivot_table(matrix_year[matrix_year['2proba'] > -100],
                      index=['Symbol', 'date_time'],
                       values=['2proba'],
                       columns=['Target'],
                       aggfunc=['mean'],
                      # margins=True
                      )
pivo2 = pd.pivot_table(matrix_year[matrix_year['2proba'] > -100],
                      index=['Symbol', 'date_time'],
                       values=['2proba', 'Pro_Morni', 'Profi_GEP', 'ProftLaBa', 'Proft1000','Proft1300','Proft1830', 'Min10',
 'Min1000',
 'Min10_1300',
 'Min10_1000',
 'Cl/min_day',
 'Cl/max_day',
 'max_day-min_day'],
                       
                       aggfunc=['mean'],
                      # margins=True
                      )
pivo3 = pd.concat([pivo1, pivo2], axis=1)

pivo3 = pivo3.reset_index()

pivo3.columns = ['Symbol',
 'date_time',
 '2proba_Pro_Morni',
 '2proba_Profi_GEP',
 '2proba_Proft1000',
 '2proba_Proft1300',
 '2proba_Proft1830',
 '2proba_ProftLaBa',
 '2proba',
 'Cl/max_day',
 'Cl/min_day',
 'Min10',
 'Min1000',
 'Min10_1000',
 'Min10_1300',
 'Pro_Morni',
 'Profi_GEP',
 'Proft1000',
 'Proft1300',
 'Proft1830',
 'ProftLaBa',
 'max_day-min_day']

pivo3['Year'] = pivo3['date_time'].dt.year

#еще комбинаторики 
pivo3['pr_comb'] = pivo3['Proft1300'].where(pivo3['Profi_GEP']<100, pivo3['Proft1000'])
pivo3
# Out:
#        Symbol           date_time  2proba_Pro_Morni  2proba_Profi_GEP  \
# 0        GAZP 2007-01-09 10:50:00          0.395738          0.613336
# 1        GAZP 2007-01-09 11:50:00          0.468902          0.598272
# 2        GAZP 2007-01-09 12:50:00          0.472617          0.565475
# 3        GAZP 2007-01-09 13:50:00          0.426713          0.545857
# 4        GAZP 2007-01-09 14:50:00          0.383038          0.535361
# ...       ...                 ...               ...               ...
# 141698   VTBR 2020-09-16 12:50:00          0.479425          0.518060
# 141699   VTBR 2020-09-16 13:50:00          0.478303          0.521970
# 141700   VTBR 2020-09-16 14:50:00          0.474455          0.528084
# 141701   VTBR 2020-09-16 15:50:00          0.468226          0.523735
# 141702   VTBR 2020-09-16 16:50:00          0.473180          0.525572
#
#         2proba_Proft1000  2proba_Proft1300  2proba_Proft1830  \
# 0               0.526596          0.539945          0.540665
# 1               0.582430          0.551400          0.566837
# 2               0.528165          0.458449          0.553901
# 3               0.458733          0.402182          0.528872
# 4               0.484571          0.432438          0.523385
# ...                  ...               ...               ...
# 141698          0.503293          0.496055          0.497135
# 141699          0.495362          0.494219          0.495304
# 141700          0.512370          0.508227          0.504152
# 141701          0.514559          0.506311          0.500392
# 141702          0.525873          0.505326          0.505367
#
#         2proba_ProftLaBa    2proba  Cl/max_day  Cl/min_day     Min10  \
# 0               0.462492  0.513129   -1.359060    0.702295 -2.771806
# 1               0.539295  0.551189   -0.570470    1.507366 -1.994509
# 2               0.489350  0.511326   -1.446309    0.613224 -2.857804
# 3               0.512750  0.479185   -1.677852    0.376841 -3.086032
# 4               0.460851  0.469941   -2.281879    0.134108 -3.681408
# ...                  ...       ...         ...         ...       ...
# 141698          0.484620  0.496431   -1.086807    0.209059 -0.346500
# 141699          0.490594  0.495959   -1.196863    0.097561 -0.457380
# 141700          0.499584  0.504479   -1.430733    0.392322 -0.693001
# 141701          0.505059  0.503047   -1.623332    0.196161 -0.887041
# 141702          0.501656  0.506162   -1.499519    0.322264 -0.762301
#
#          Min1000  Min10_1000  Min10_1300  Pro_Morni  Profi_GEP  Proft1000  \
# 0       0.190872   -2.877817   -2.826446   0.203359  -0.512767  -2.973295
# 1       0.991854   -2.101368   -2.049587   0.203359  -0.512767  -3.742828
# 2       0.102253   -2.963722   -2.912397   0.203359  -0.512767  -2.887398
# 3      -0.132929   -3.191700   -3.140496   0.203359  -0.512767  -2.658703
# 4      -0.746447   -3.786427   -3.735537   0.203359  -0.512767  -2.057005
# ...          ...         ...         ...        ...        ...        ...
# 141698 -0.882272    0.531320   -0.041707  -0.394033  -0.768049  -1.168289
# 141699 -0.992556    0.419463   -0.152926  -0.394033  -0.768049  -1.058201
# 141700 -1.226909    0.181767   -0.389267  -0.394033  -0.768049  -0.823447
# 141701 -1.419906   -0.013982   -0.583901  -0.394033  -0.768049  -0.629283
# 141702 -1.295837    0.111857   -0.458779  -0.394033  -0.768049  -0.754190
#
#         Proft1300  Proft1830  ProftLaBa  max_day-min_day  Year   pr_comb
# 0       -2.775982  -0.741623  -2.473210         2.075183  2007 -2.775982
# 1       -3.547081  -1.528856  -3.246709         2.058724  2007 -3.547081
# 2       -2.689911  -0.653751  -2.386871         2.077020  2007 -2.689911
# 3       -2.460751  -0.419795  -2.156997         2.081911  2007 -2.460751
# 4       -1.857830   0.195742  -1.552198         2.469093  2007 -1.857830
# ...           ...        ...        ...              ...   ...       ...
# 141698  -1.557719  -0.834492  -0.403338         1.307371  2020 -1.557719
# 141699  -1.448065  -0.724032  -0.292398         1.308828  2020 -1.448065
# 141700  -1.214236  -0.488486  -0.055827         1.842289  2020 -1.214236
# 141701  -1.020836  -0.293665   0.139841         1.845896  2020 -1.020836
# 141702  -1.145251  -0.418994   0.013966         1.843575  2020 -1.145251
#
# [141703 rows x 24 columns]

# %%
matrix_year[matrix_year['date_time'] =='2020-09-14 16:50:00'][['date_time','Proft1000', 'Symbol']]
# Out:
#                  date_time  Proft1000 Symbol
# 748115 2020-09-14 16:50:00  -0.246278   GAZP
# 748291 2020-09-14 16:50:00  -0.153453   GMKN
# 748467 2020-09-14 16:50:00  -0.409492   LKOH
# 748643 2020-09-14 16:50:00   0.320984   ROSN
# 748819 2020-09-14 16:50:00   1.056604   SBER
# 748995 2020-09-14 16:50:00   0.491780   VTBR
# 768359 2020-09-14 16:50:00  -0.246278   GAZP
# 768535 2020-09-14 16:50:00  -0.153453   GMKN
# 768711 2020-09-14 16:50:00  -0.409492   LKOH
# 768887 2020-09-14 16:50:00   0.320984   ROSN
# 769063 2020-09-14 16:50:00   1.056604   SBER
# 769239 2020-09-14 16:50:00   0.491780   VTBR
# 788603 2020-09-14 16:50:00  -0.246278   GAZP
# 788779 2020-09-14 16:50:00  -0.153453   GMKN
# 788955 2020-09-14 16:50:00  -0.409492   LKOH
# 789131 2020-09-14 16:50:00   0.320984   ROSN
# 789307 2020-09-14 16:50:00   1.056604   SBER
# 789483 2020-09-14 16:50:00   0.491780   VTBR
# 808847 2020-09-14 16:50:00  -0.246278   GAZP
# 809023 2020-09-14 16:50:00  -0.153453   GMKN
# 809199 2020-09-14 16:50:00  -0.409492   LKOH
# 809375 2020-09-14 16:50:00   0.320984   ROSN
# 809551 2020-09-14 16:50:00   1.056604   SBER
# 809727 2020-09-14 16:50:00   0.491780   VTBR
# 829091 2020-09-14 16:50:00  -0.246278   GAZP
# 829267 2020-09-14 16:50:00  -0.153453   GMKN
# 829443 2020-09-14 16:50:00  -0.409492   LKOH
# 829619 2020-09-14 16:50:00   0.320984   ROSN
# 829795 2020-09-14 16:50:00   1.056604   SBER
# 829971 2020-09-14 16:50:00   0.491780   VTBR
# 849335 2020-09-14 16:50:00  -0.246278   GAZP
# 849511 2020-09-14 16:50:00  -0.153453   GMKN
# 849687 2020-09-14 16:50:00  -0.409492   LKOH
# 849863 2020-09-14 16:50:00   0.320984   ROSN
# 850039 2020-09-14 16:50:00   1.056604   SBER
# 850215 2020-09-14 16:50:00   0.491780   VTBR

# %%
pd.options.display.max_columns = 100
pivo3[pivo3['Date'] == '2020-09-14 16:50:00']
#matrix_year[matrix_year['date_time'] == '2012-01-04 12:50:00'][['date_time', 'Close_x', 'Symbol', 'Proft1000', 'Close_y']]
# Out:
#        Symbol                Date  2proba_Pro_Morni  2proba_Profi_GEP  \
# 23722    GAZP 2020-09-14 16:50:00          0.472018          0.519157
# 47459    GMKN 2020-09-14 16:50:00          0.471529          0.520252
# 71196    LKOH 2020-09-14 16:50:00          0.472018          0.517888
# 94933    ROSN 2020-09-14 16:50:00          0.472981          0.533923
# 118642   SBER 2020-09-14 16:50:00          0.477545          0.527601
# 141688   VTBR 2020-09-14 16:50:00          0.475649          0.520159
#
#         2proba_Proft1000  2proba_Proft1300  2proba_Proft1830  \
# 23722           0.511671          0.503987          0.504201
# 47459           0.520429          0.504871          0.505562
# 71196           0.516519          0.506108          0.504007
# 94933           0.526721          0.506704          0.504007
# 118642          0.544157          0.541513          0.508043
# 141688          0.518461          0.502797          0.502310
#
#         2proba_ProftLaBa    2proba  Pro_Morni  Profi_GEP  Proft1000  \
# 23722           0.515003  0.504340  -1.183628   0.483690   0.404631
# 47459           0.508162  0.505134  -0.356779   0.721278   0.887604
# 71196           0.513503  0.505007  -0.884587   0.612719   0.580843
# 94933           0.505278  0.508269  -0.809233   0.863348   0.646117
# 118642          0.558727  0.526264  -0.243578   1.404583   2.140298
# 141688          0.501861  0.503540  -0.808362   0.295941   0.579423
#
#         Proft1300  Proft1830  ProftLaBa     Min10   Min1000  Min10_1300  \
# 23722   -0.329149   2.867342   1.667331  1.172708  0.349099   -0.246278
# 47459   -0.061343   0.814769   0.638320  0.942623  0.215628   -0.153453
# 71196    0.126156   2.342575   2.024638  1.476015  0.137247   -0.409492
# 94933    0.241319   2.172725   1.163577  0.733236  0.657542    0.320984
# 118642   1.045218   2.349146   1.486821  1.234459  0.246620    1.056604
# 141688  -0.447615   1.251956   0.893110  0.573266  0.224215    0.491780
#
#         Min10_1000  Cl/min_day  Cl/max_day  max_day-min_day  Year   pr_comb
# 23722     0.923542    2.345237   -0.593306         1.679167  2020 -0.329149
# 47459     0.787724    0.163683   -0.368286         1.074169  2020 -0.061343
# 71196     1.060479    2.393952   -0.545989         1.501470  2020  0.126156
# 94933     1.056573    2.875485   -0.334359         1.671794  2020  0.241319
# 118642    2.304107    2.685905    0.807991         1.629301  2020  1.045218
# 141688    1.067866    1.376985    0.266966         1.110018  2020 -0.447615

# %%
aa = pd.pivot_table(pivo3[(pivo3['2proba_Proft1000'] >= 0.55)&(pivo3['date_time'].dt.year >= 2010)],
                    index=['date_time'],
                    values=['Proft1000'],
                    aggfunc=['count', 'mean', 'max', 'min'],
                    margins=True
                   )
display(aa.shape)
aa
# Out:
# (6167, 4)
#                         count      mean        max        min
#                     Proft1000 Proft1000  Proft1000  Proft1000
# date_time
# 2010-01-11 12:50:00         6 -0.682498   0.713357  -3.963012
# 2010-01-11 13:50:00         5 -0.318087   0.507972  -1.549681
# 2010-01-11 14:50:00         5  0.080753   0.732070  -0.894701
# 2010-01-11 15:50:00         6 -0.385609   0.108052  -1.257143
# 2010-01-11 16:50:00         6 -0.670481  -0.182004  -1.695301
# ...                       ...       ...        ...        ...
# 2020-09-15 14:50:00         2  1.384846   1.684232   1.085459
# 2020-09-15 15:50:00         4  1.174495   2.018613   0.198601
# 2020-09-15 16:50:00         5  0.168549   1.407166  -3.018944
# 2020-09-16 13:50:00         1 -1.259160  -1.259160  -1.259160
# All                     13888  0.287590  21.046892 -11.996872
#
# [6167 rows x 4 columns]

# %%
#УБРАТЬ СДВОЕННОСТИ DEF +комбинаторика (МИН ПРОБА БОЛЬШЕ 0,55 ДЛЯ 4 ТАРГЕТОВ)
tresh_comb = 0.55

pivo3_55_inday = pd.pivot_table(pivo3[pivo3[[ '2proba_Proft1000','2proba_Proft1300','2proba_Proft1830','2proba_ProftLaBa']].min(axis=1) > tresh_comb], 
                          index = 'Date', values = ['Pro_Morni','Profi_GEP','Proft1000','Proft1300','Proft1830','ProftLaBa', 'pr_comb'], aggfunc=['mean', 'count'],
                         # margins=True
                         ) 
display(pivo3_55_inday.shape)

#СМОТРИМ ЧАСЫ И УВБИРАЕМ НЕНУЖНОЕ
pivo3_55_inday.columns = ['Pro_Morni','Profi_GEP','Proft1000','Proft1300','Proft1830','ProftLaBa', 'pr_comb', 'cPro_Morni','cProfi_GEP','cProft1000','cProft1300','cProft1830','cProftLaBa', 'cpr_comb']
pivo4 = pd.pivot_table(pivo3_55_inday, index=[pivo3_55_inday.index.year], values = ['Pro_Morni','Profi_GEP','Proft1000','Proft1300','Proft1830','ProftLaBa'], 
                       aggfunc=['mean', 'count'],
                       margins=True
                      )
#display(pivo4)

#уберем 2 первых часа 
pivo3_55_inday = pivo3_55_inday[pivo3_55_inday.index.time<=datetime.time(20,50,0)]

k1 = []
for oo in range(len(pivo3_55_inday)):
    if pivo3_55_inday.index[oo].date() != pivo3_55_inday.index[oo-1].date():
        k = 1
    else:
        k+=1
    k1.append(k)
        
pivo3_55_inday['long'] = k1


display(pivo3_55_inday.shape)
pivo3_55_inday = pivo3_55_inday[pivo3_55_inday.index.year.isin([2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020])] #убрали годы
display(pivo3_55_inday.shape)

pivo3_55_inday = pivo3_55_inday[pivo3_55_inday['long'] == 1] #первый на дню
display(pivo3_55_inday.shape)

pivo3_55_inday = pd.pivot_table(pivo3_55_inday, 
                          index = pivo3_55_inday.index.year, values = ['Pro_Morni','Profi_GEP','Proft1000','Proft1300','Proft1830','ProftLaBa', 'pr_comb'], aggfunc=['mean', 'count'],
                          margins=True
                         )  
pivo3_55_inday
# Out:
# (2442, 14)
# (2442, 15)
# (796, 15)
# (398, 15)
#           mean                                                              \
#      Pro_Morni Profi_GEP Proft1000 Proft1300 Proft1830 ProftLaBa   pr_comb
# Date
# 2010 -0.429564  3.289816  3.537522  2.521995  4.329677  3.926288  2.521995
# 2011 -0.355128  3.240955  2.713244  2.362135  2.669867  2.807588  2.362135
# 2012 -0.283930  3.176094  3.197505  2.497081  3.768702  3.699320  2.497081
# 2013 -0.374124  3.649006  3.439551  2.933503  4.753820  4.346353  2.933503
# 2014 -0.753210  3.922232  2.835553  2.673360  1.987617  2.393350  2.673360
# 2015 -0.348115  3.489964  3.342769  2.602083  3.954994  3.540913  2.602083
# 2016 -0.245734  3.447384  3.256392  2.815076  4.019591  3.706496  2.815076
# 2017 -0.251137  2.944259  2.869512  2.404518  3.026785  3.312083  2.404518
# 2018 -0.542947  3.573655  3.128422  2.581221  3.769702  3.694950  2.581221
# 2019 -0.589416  3.916144  3.435524  2.984740  3.760812  3.549989  2.984740
# 2020 -0.911704  3.337696  2.099047  1.731010  1.054695  1.256780  1.731010
# All  -0.466008  3.454076  3.050759  2.529325  3.285039  3.204792  2.529325
#
#          count
#      Pro_Morni Profi_GEP Proft1000 Proft1300 Proft1830 ProftLaBa pr_comb
# Date
# 2010        28        28        28        28        28        28      28
# 2011        40        40        40        40        40        40      40
# 2012        22        22        22        22        22        22      22
# 2013        15        15        15        15        15        15      15
# 2014        37        37        37        37        37        37      37
# 2015        70        70        70        70        70        70      70
# 2016        42        42        42        42        42        42      42
# 2017        34        34        34        34        34        34      34
# 2018        38        38        38        38        38        38      38
# 2019        31        31        31        31        31        31      31
# 2020        41        41        41        41        41        41      41
# All        398       398       398       398       398       398     398

# %%
#БЕЗ КОМБИНАТОРИКА И СДВОЕННОСТИ
tresh = 0.6
from__ = '10:50:00'
ff_all = ['Proft1000','Proft1300','Proft1830','ProftLaBa']

#sort = 'Year'
#sort1 = year

simple_all = pd.DataFrame()

for ff in ff_all:
    display(from__, tresh)
    #*******
    display('все')
    simple1 = pd.pivot_table(matrix_year[(matrix_year['2proba']>=tresh)&(matrix_year['Target'] == ff)&(matrix_year['Time'] >= from__)],
                          index=matrix_year['date_time'].dt.year,
                           values=[ff],
                           aggfunc=['mean', 'count'],
                           margins=True
                          )
 #   display(simple1)
    #***********


    #22222222222222222
    simple = pd.pivot_table(matrix_year[(matrix_year['2proba']>=tresh)&(matrix_year['Target'] == ff)&(matrix_year['Time'] >= from__)],
                          index=['date_time'],
                           values=[ff],
                           aggfunc=['mean', 'count'],
                    #       margins=True
                          )
    simple.columns = [ff, 'count']
    display('по дням')
    simple2 = pd.pivot_table(simple,
                           index=simple.index.year,
                           values=[ff],
                           aggfunc=['mean', 'count'],
                           margins=True
                          )
  #  display(simple2)
    #22222222222222222222222


    k1 = []
    for oo in range(len(simple)):
        if simple.index[oo].date() != simple.index[oo-1].date():
            k = 1
        else:
            k+=1
        k1.append(k)
    k1        
    simple['long'] = k1

    simple.columns = [ff, 'count', 'long']

    #333333333333333333333
    display('по 1 по часам')
    simple = simple[simple['long'] == 1]
    simple3 = pd.pivot_table(simple,
                           index=simple.index.year,
                           values=[ff],
                           aggfunc=['mean', 'count'],
                           margins=True
                          )
 #   display(simple3)
    
    simple_all = pd.concat([simple1, simple2], axis=1)
    simple_all = pd.concat([simple_all, simple3], axis=1)
    display(simple_all)
    simple_all = pd.DataFrame()
    
    #3333333333333333
# Out:
# '10:50:00'
# 0.6
# 'все'
# 'по дням'
# 'по 1 по часам'
#                mean     count      mean     count      mean     count
#           Proft1000 Proft1000 Proft1000 Proft1000 Proft1000 Proft1000
# date_time
# 2007       0.524001      1469  0.508144       667  0.324062       196
# 2008       0.478149      1885  0.255652       672  0.228234       181
# 2009       1.065001      1330  1.337948       505  1.199509       165
# 2010       0.466340       426  0.371156       215  0.310403       114
# 2011       0.578734       503  0.495772       260  0.389560        99
# 2012       0.094591       188  0.108034       123  0.162476        49
# 2013       0.359585       149  0.365611       113  0.271495        50
# 2014       0.651759       419  0.813483       238  0.488566        77
# 2015       0.343686       453  0.231336       258  0.092294        98
# 2016       0.563459       275  0.599181       197  0.485210        62
# 2017       0.139635       139  0.131038       110  0.156302        48
# 2018       0.596724       200  0.670131       155  0.681837        54
# 2019       0.296652       175  0.372301       160  0.594877        54
# 2020       0.834589       306  0.758687       161  0.402472        60
# All        0.590934      7917  0.553216      3834  0.440379      1307
# '10:50:00'
# 0.6
# 'все'
# 'по дням'
# 'по 1 по часам'
#                mean     count      mean     count      mean     count
#           Proft1300 Proft1300 Proft1300 Proft1300 Proft1300 Proft1300
# date_time
# 2007       0.405656       934  0.414546       538  0.258348       186
# 2008       0.281353      1407 -0.029076       553 -0.047986       165
# 2009       0.657748       647  0.960977       305  1.010961       134
# 2010       1.348290        16  1.415478        10  1.424967         7
# 2011       0.907567        46  0.670527        25  0.984230        19
# 2012       1.189558         8  1.793185         4  2.410746         2
# 2013       1.494160         3  1.494160         3  1.494160         3
# 2014       1.613018        51  1.001026        36  1.398048        22
# 2015      -0.830314        11 -0.830314        11 -0.830314        11
# 2016       0.727294        22  0.569588        20  0.552072        19
# 2017       0.278555         4  0.278555         4  0.278555         4
# 2018      -0.414449        14  0.462922        10  1.229354         6
# 2019       1.068477         3  1.068477         3  1.068477         3
# 2020      -0.850384        46 -1.194558        21  0.419564        15
# All        0.412877      3212  0.366025      1543  0.442425       596
# '10:50:00'
# 0.6
# 'все'
# 'по дням'
# 'по 1 по часам'
#                mean     count      mean     count      mean     count
#           Proft1830 Proft1830 Proft1830 Proft1830 Proft1830 Proft1830
# date_time
# 2007       0.256874      1226  0.263582       663  0.288235       214
# 2008       0.405881       683  0.191106       307  0.130122       119
# 2009      -0.801134        16  0.933439         8  2.750186         6
# 2011       1.520737         1  1.520737         1  1.520737         1
# 2012       4.156075         1  4.156075         1  4.156075         1
# 2014       6.923870         2  6.923870         2  6.923870         2
# 2015       0.100954         4  0.100954         4  0.100954         4
# 2018       0.472359         7  0.706616         6  1.128499         3
# 2020      -2.264188         6 -2.497339         4 -2.497339         4
# All        0.302659      1946  0.256095       996  0.302239       354
# '10:50:00'
# 0.6
# 'все'
# 'по дням'
# 'по 1 по часам'
#                mean     count      mean     count      mean     count
#           ProftLaBa ProftLaBa ProftLaBa ProftLaBa ProftLaBa ProftLaBa
# date_time
# 2007       0.364668       565  0.345915       298  0.244925       130
# 2008       0.396915      1034  0.273159       420  0.165239       129
# 2009       0.419654       734  0.424960       328  0.467349       131
# 2010       0.380382       153  0.326655        93  0.362110        57
# 2011       0.135717       132  0.161883        86  0.124885        47
# 2012       0.312931        60  0.313058        48  0.378056        26
# 2013       0.120898        69  0.179777        55  0.159045        30
# 2014      -0.181964       135 -0.105016        94  0.036840        49
# 2015       0.143677       125  0.146864        81  0.137656        53
# 2016       0.404413        78  0.455037        57  0.548072        32
# 2017      -0.005769        49 -0.046140        37 -0.012296        27
# 2018       0.040061        43  0.055777        34  0.010534        30
# 2019      -0.079771        50 -0.042185        48  0.131511        30
# 2020       0.293338        62  0.252629        34  0.203707        25
# All        0.324804      3289  0.269193      1713  0.240139       796

# %%
#сравниваем pivo3 and pivo3
tresh_comb = 0.55
tresh      = 0.55

pivo3_00 = pd.pivot_table(matrix_year[matrix_year['2proba'] > tresh],
                      index=['Year'],
                       values=['Profit_carrent'],
                       columns=['Target'],
                       aggfunc=['mean', 'count'],
                       margins=True
                      )
display(pivo3_00)
pivo3_r = pivo3[pivo3['Date'].dt.year.isin([2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020])] #убрали годы
pivo3_55 = pd.pivot_table(pivo3_r[pivo3_r[['2proba_Proft1000','2proba_Proft1300','2proba_Proft1830','2proba_ProftLaBa']].min(axis=1) > tresh_comb], 
                          index = 'Year', values = ['Pro_Morni','Profi_GEP','Proft1000','Proft1300','Proft1830','ProftLaBa'], aggfunc=['mean', 'count'],
                          margins=True
                         )                    
pivo3_55
# Out:
#                  mean                                                    \
#        Profit_carrent
# Target      Pro_Morni Profi_GEP Proft1000 Proft1300 Proft1830 ProftLaBa
# Year
# 2013         0.221933  0.039703  0.003312 -0.072210 -0.081161  0.070014
# 2014        -0.153860 -0.006602  0.150997  0.288552  0.971968  0.117365
# 2015         0.420470  0.127889  0.257426  0.431788  0.265768  0.040081
# 2016         0.226690  0.082537  0.291916  0.381296  0.567922  0.238870
# 2017        -1.012785  0.055967  0.212954  0.109347  0.361057  0.085000
# 2018        -0.409289  0.137041  0.271818  0.461695  0.855652  0.172516
# 2019              NaN  0.132948  0.181958  0.140468  0.181860  0.036395
# 2020         0.106161  0.499292  0.359150  0.543712  0.015755  0.046192
# All          0.026521  0.082258  0.192117  0.304096  0.310668  0.093282
#
#                           count                                          \
#                  Profit_carrent
# Target       All      Pro_Morni Profi_GEP Proft1000 Proft1300 Proft1830
# Year
# 2013    0.023239          294.0    6216.0    1866.0     727.0     812.0
# 2014    0.064220          348.0    6615.0    1076.0     525.0     325.0
# 2015    0.160454           41.0    6062.0     719.0     510.0     531.0
# 2016    0.200847           63.0    2992.0     804.0     780.0     348.0
# 2017    0.102109           14.0    1854.0     468.0     478.0     194.0
# 2018    0.293485           31.0    1584.0    1161.0     834.0     366.0
# 2019    0.138258            NaN     817.0     440.0     371.0     156.0
# 2020    0.342058           58.0    1188.0    1027.0     746.0     514.0
# All     0.138171          849.0   27328.0    7561.0    4971.0    3246.0
#
#
#
# Target ProftLaBa    All
# Year
# 2013       654.0  10569
# 2014       719.0   9608
# 2015       642.0   8505
# 2016       280.0   5267
# 2017       258.0   3266
# 2018       424.0   4400
# 2019       221.0   2005
# 2020       586.0   4119
# All       3784.0  47739
#           mean                                                       count  \
#      Pro_Morni Profi_GEP Proft1000 Proft1300 Proft1830 ProftLaBa Pro_Morni
# Year
# 2013 -0.084914  0.078993  0.251480  0.164307  0.222598  0.174426        43
# 2014 -0.062044  0.122112  0.592509  0.521466  1.135769  0.458666        63
# 2015  0.259475  0.267623 -0.016546  0.244914 -0.015328 -0.284305       176
# 2016  0.102474  0.120748  0.334622  0.433307  0.674179  0.210498       118
# 2017 -0.034213  0.068472  0.146437  0.113588  0.256321  0.079754       101
# 2018  0.039574  0.291856  0.393046  0.436970  0.749776  0.108499       184
# 2019 -0.242216  0.267918  0.247517  0.000777  0.123314 -0.021263        83
# 2020 -0.301899  0.441872  0.509537  0.218576 -0.158225  0.054835       193
# All  -0.025333  0.250338  0.302508  0.279165  0.313762  0.049984       961
#
#
#      Profi_GEP Proft1000 Proft1300 Proft1830 ProftLaBa
# Year
# 2013        43        43        43        43        43
# 2014        63        63        63        63        63
# 2015       176       176       176       176       176
# 2016       118       118       118       118       118
# 2017       101       101       101       101       101
# 2018       184       184       184       184       184
# 2019        83        83        83        83        83
# 2020       193       193       193       193       193
# All        961       961       961       961       961

# %%
pivo3
# Out:
#       Symbol                Date  2proba_Pro_Morni  2proba_Profi_GEP  \
# 0       GAZP 2007-01-09 10:50:00          0.395738          0.613336
# 1       GAZP 2007-01-09 11:50:00          0.468902          0.598272
# 2       GAZP 2007-01-09 12:50:00          0.472617          0.565475
# 3       GAZP 2007-01-09 13:50:00          0.426713          0.545857
# 4       GAZP 2007-01-09 14:50:00          0.383038          0.535361
# ...      ...                 ...               ...               ...
# 18855   VTBR 2008-12-30 12:50:00          0.507155          0.512669
# 18856   VTBR 2008-12-30 13:50:00          0.518604          0.523268
# 18857   VTBR 2008-12-30 14:50:00          0.511704          0.523566
# 18858   VTBR 2008-12-30 15:50:00          0.472149          0.553458
# 18859   VTBR 2008-12-30 16:50:00          0.501400          0.539015
#
#        2proba_Proft1000  2proba_Proft1300  2proba_Proft1830  2proba_ProftLaBa  \
# 0              0.526596          0.539945          0.540665          0.462492
# 1              0.582430          0.551400          0.566837          0.539295
# 2              0.528165          0.458449          0.553901          0.489350
# 3              0.458733          0.402182          0.528872          0.512750
# 4              0.484571          0.432438          0.523385          0.460851
# ...                 ...               ...               ...               ...
# 18855          0.508013          0.477876          0.500733          0.478646
# 18856          0.514906          0.513207          0.500021          0.483106
# 18857          0.528291          0.524974          0.498319          0.504399
# 18858          0.564069          0.551498          0.507597          0.519710
# 18859          0.535342          0.523867          0.539537          0.474824
#
#          2proba  Pro_Morni  Profi_GEP  Proft1000  Proft1300  Proft1830  \
# 0      0.513129   0.203359  -0.512767  -2.973295  -2.775982  -0.741623
# 1      0.551189   0.203359  -0.512767  -3.742828  -3.547081  -1.528856
# 2      0.511326   0.203359  -0.512767  -2.887398  -2.689911  -0.653751
# 3      0.479185   0.203359  -0.512767  -2.658703  -2.460751  -0.419795
# 4      0.469941   0.203359  -0.512767  -2.057005  -1.857830   0.195742
# ...         ...        ...        ...        ...        ...        ...
# 18855  0.497515   4.504505  -1.479290  -0.597015   3.880597   1.492537
# 18856  0.508852   4.504505  -1.479290  -0.892857   3.571429   1.190476
# 18857  0.515209   4.504505  -1.479290  -0.892857   3.571429   1.190476
# 18858  0.528080   4.504505  -1.479290  -1.769912   2.654867   0.294985
# 18859  0.518997   4.504505  -1.479290  -1.186944   3.264095   0.890208
#
#        ProftLaBa  Year
# 0      -2.473210  2007
# 1      -3.246709  2007
# 2      -2.386871  2007
# 3      -2.156997  2007
# 4      -1.552198  2007
# ...          ...   ...
# 18855   0.895522  2008
# 18856   0.595238  2008
# 18857   0.595238  2008
# 18858  -0.294985  2008
# 18859   0.296736  2008
#
# [18860 rows x 16 columns]

# %%
# ФУНКЦИЯ КОТОАРЯ РАБОТАЕТ ТОЛЬКО С  matrix_year ОЛЬШЕ НИЧЕГО ЕЙ НЕ НУЖНО

#переменные
na_re = 4 #число  совпаlений
#profit_anal = 'Proft1000' # какую профит смотрим СМОТРИМ ВСЕ В ЦИКЛЕ
tresh = 0.55 #порог

# %%
pivo1 = pd.pivot_table(matrix_year[matrix_year['2proba'] > tresh],
                      index=['date_time'],
                       values=['Profit_carrent'],
                       columns=['Target'],
                       aggfunc=['mean','count'],
                      # margins=True
                      )
display(pivo1.head(10))
pivo1.columns = ['Pro_Morni','Profi_GEP','Proft1000','Proft1300','Proft1830','ProftLaBa',   'C_Pro_Morni','C_Profi_GEP','C_Proft1000','C_Proft1300','C_Proft1830','C_ProftLaBa',]
#pivo1.columns = ['Proft1000','Proft1300','ProftLaBa',   'C_Proft1000','C_Proft1300','C_ProftLaBa',]

pivo1['namber'] = pivo1[['Proft1000','Proft1300','Proft1830','ProftLaBa']].apply(lambda x: x.notnull().sum(), axis='columns') # берем только таргеты 4 без гэпа и морнинга
display(pivo1.head(10))
# Out:
#                               mean                                          \
#                     Profit_carrent
# Target                   Pro_Morni Profi_GEP Proft1000 Proft1300 Proft1830
# date_time
# 2013-01-08 10:50:00       0.544743       NaN       NaN  0.315247  0.032649
# 2013-01-08 11:50:00       0.711864       NaN  0.049823  0.922982       NaN
# 2013-01-08 12:50:00            NaN       NaN  0.337216  0.562027  0.378091
# 2013-01-08 13:50:00            NaN       NaN -0.140313  0.469627 -0.201460
# 2013-01-08 14:50:00            NaN       NaN -0.143936  0.077111  0.224467
# 2013-01-08 15:50:00            NaN -0.933155 -1.234248       NaN       NaN
# 2013-01-08 16:50:00            NaN -0.933155 -0.341300  0.071182       NaN
# 2013-01-09 10:50:00            NaN -0.013542       NaN       NaN       NaN
# 2013-01-09 11:50:00            NaN  0.249486  0.377744       NaN       NaN
# 2013-01-09 12:50:00            NaN -0.018606       NaN       NaN       NaN
#
#                                        count                                \
#                               Profit_carrent
# Target              ProftLaBa      Pro_Morni Profi_GEP Proft1000 Proft1300
# date_time
# 2013-01-08 10:50:00  0.222249            4.0       NaN       NaN       2.0
# 2013-01-08 11:50:00  0.178347            1.0       NaN       2.0       1.0
# 2013-01-08 12:50:00  0.225591            NaN       NaN       1.0       1.0
# 2013-01-08 13:50:00  0.050045            NaN       NaN       2.0       1.0
# 2013-01-08 14:50:00 -0.262490            NaN       NaN       2.0       2.0
# 2013-01-08 15:50:00 -0.142114            NaN       1.0       1.0       NaN
# 2013-01-08 16:50:00  0.010005            NaN       1.0       2.0       1.0
# 2013-01-09 10:50:00       NaN            NaN       5.0       NaN       NaN
# 2013-01-09 11:50:00       NaN            NaN       6.0       1.0       NaN
# 2013-01-09 12:50:00       NaN            NaN       4.0       NaN       NaN
#
#
#
# Target              Proft1830 ProftLaBa
# date_time
# 2013-01-08 10:50:00       2.0       2.0
# 2013-01-08 11:50:00       NaN       2.0
# 2013-01-08 12:50:00       1.0       4.0
# 2013-01-08 13:50:00       2.0       3.0
# 2013-01-08 14:50:00       1.0       6.0
# 2013-01-08 15:50:00       NaN       4.0
# 2013-01-08 16:50:00       NaN       3.0
# 2013-01-09 10:50:00       NaN       NaN
# 2013-01-09 11:50:00       NaN       NaN
# 2013-01-09 12:50:00       NaN       NaN
#                      Pro_Morni  Profi_GEP  Proft1000  Proft1300  Proft1830  \
# date_time
# 2013-01-08 10:50:00   0.544743        NaN        NaN   0.315247   0.032649
# 2013-01-08 11:50:00   0.711864        NaN   0.049823   0.922982        NaN
# 2013-01-08 12:50:00        NaN        NaN   0.337216   0.562027   0.378091
# 2013-01-08 13:50:00        NaN        NaN  -0.140313   0.469627  -0.201460
# 2013-01-08 14:50:00        NaN        NaN  -0.143936   0.077111   0.224467
# 2013-01-08 15:50:00        NaN  -0.933155  -1.234248        NaN        NaN
# 2013-01-08 16:50:00        NaN  -0.933155  -0.341300   0.071182        NaN
# 2013-01-09 10:50:00        NaN  -0.013542        NaN        NaN        NaN
# 2013-01-09 11:50:00        NaN   0.249486   0.377744        NaN        NaN
# 2013-01-09 12:50:00        NaN  -0.018606        NaN        NaN        NaN
#
#                      ProftLaBa  C_Pro_Morni  C_Profi_GEP  C_Proft1000  \
# date_time
# 2013-01-08 10:50:00   0.222249          4.0          NaN          NaN
# 2013-01-08 11:50:00   0.178347          1.0          NaN          2.0
# 2013-01-08 12:50:00   0.225591          NaN          NaN          1.0
# 2013-01-08 13:50:00   0.050045          NaN          NaN          2.0
# 2013-01-08 14:50:00  -0.262490          NaN          NaN          2.0
# 2013-01-08 15:50:00  -0.142114          NaN          1.0          1.0
# 2013-01-08 16:50:00   0.010005          NaN          1.0          2.0
# 2013-01-09 10:50:00        NaN          NaN          5.0          NaN
# 2013-01-09 11:50:00        NaN          NaN          6.0          1.0
# 2013-01-09 12:50:00        NaN          NaN          4.0          NaN
#
#                      C_Proft1300  C_Proft1830  C_ProftLaBa  namber
# date_time
# 2013-01-08 10:50:00          2.0          2.0          2.0       3
# 2013-01-08 11:50:00          1.0          NaN          2.0       3
# 2013-01-08 12:50:00          1.0          1.0          4.0       4
# 2013-01-08 13:50:00          1.0          2.0          3.0       4
# 2013-01-08 14:50:00          2.0          1.0          6.0       4
# 2013-01-08 15:50:00          NaN          NaN          4.0       2
# 2013-01-08 16:50:00          1.0          NaN          3.0       3
# 2013-01-09 10:50:00          NaN          NaN          NaN       0
# 2013-01-09 11:50:00          NaN          NaN          NaN       1
# 2013-01-09 12:50:00          NaN          NaN          NaN       0

# %%
pivo1.describe()
pivo2 = pivo1[pivo1['namber'] >= na_re]
k1 = []
for oo in range(len(pivo2)):
    if pivo2.index[oo].date() != pivo2.index[oo-1].date():
        k = 1
    else:
        k+=1
    k1.append(k)
k1        
pivo2['long'] = k1

pivo2
pivo3 = pivo2[pivo2['long'] == 1] #первый на дню
for ll in ['Pro_Morni','Profi_GEP','Proft1000','Proft1300','Proft1830','ProftLaBa']:
    pivo4 = pd.pivot_table(pivo3,
                          index = pivo3.index.year,
                           values=ll,
                           aggfunc=['mean', 'count', 'min', 'max'],
                           margins=True
                          )  


    display(pivo4)
# Out:
#           mean     count       min       max
#      Pro_Morni Pro_Morni Pro_Morni Pro_Morni
# 2013 -0.151517         8 -1.588776  1.673374
# 2014  0.085346        26 -3.004604  3.182822
# 2016  0.917915         2  0.073099  1.762731
# 2020  2.806122         1  2.806122  2.806122
# All   0.152671        37 -3.004604  3.182822
# 2015       NaN         0       NaN       NaN
# 2017       NaN         0       NaN       NaN
# 2018       NaN         0       NaN       NaN
# 2019       NaN         0       NaN       NaN
#                mean     count       min       max
#           Profi_GEP Profi_GEP Profi_GEP Profi_GEP
# date_time
# 2013       0.089720        33 -1.490674  1.449119
# 2014       0.220078        51 -3.318145  3.153635
# 2015       0.186609        89 -1.658631  1.766192
# 2016      -0.017190        54 -3.728829  2.426628
# 2017       0.221883        43 -0.789376  1.653536
# 2018       0.227963        64 -3.519856  2.755452
# 2019       0.249801        43 -1.004855  1.902039
# 2020       0.203353        59 -9.701711  5.379607
# All        0.175997       436 -9.701711  5.379607
#                mean     count        min        max
#           Proft1000 Proft1000  Proft1000  Proft1000
# date_time
# 2013       0.046302        43  -2.016528   2.682682
# 2014       0.248693        59  -9.464504   7.074560
# 2015       0.232345        91  -4.124281   5.391246
# 2016       0.306787        56  -4.261636   3.595708
# 2017       0.223954        51  -3.057516   2.449694
# 2018       0.463755        69  -7.089422   4.141462
# 2019       0.206070        48  -3.020797   3.869262
# 2020      -0.019549        65 -11.996872  13.047309
# All        0.222051       482 -11.996872  13.047309
#                mean     count        min        max
#           Proft1300 Proft1300  Proft1300  Proft1300
# date_time
# 2013       0.173158        43  -3.095238   4.153570
# 2014       0.592993        59  -8.879282  19.245142
# 2015       0.292177        91  -6.141367   7.688832
# 2016       0.355098        56  -3.334926   4.753863
# 2017       0.239735        51  -4.703870   3.656809
# 2018       0.588141        69 -10.200760   8.001873
# 2019       0.013981        48  -3.029040   2.979275
# 2020       0.157894        65 -11.823989  17.402873
# All        0.316698       482 -11.823989  19.245142
#                mean     count        min        max
#           Proft1830 Proft1830  Proft1830  Proft1830
# date_time
# 2013      -0.240496        43  -8.423493   4.100812
# 2014       0.948807        59  -3.526871  17.806428
# 2015       0.019670        91  -6.701429   6.281883
# 2016       0.618338        56  -3.744947   6.406185
# 2017       0.322262        51  -3.819137   4.955642
# 2018       0.610348        69  -8.844276   6.553540
# 2019      -0.023195        48  -3.185397   2.582765
# 2020      -0.185373        65 -15.047554  11.813594
# All        0.264402       482 -15.047554  17.806428
#                mean     count       min        max
#           ProftLaBa ProftLaBa ProftLaBa  ProftLaBa
# date_time
# 2013      -0.010467        43 -1.687052   3.053435
# 2014       0.240309        59 -5.104799   4.993723
# 2015      -0.057218        91 -3.639540   3.447693
# 2016       0.365460        56 -1.823570   2.806324
# 2017       0.087976        51 -3.789279   1.757114
# 2018       0.176102        69 -5.967293   5.347178
# 2019      -0.003540        48 -2.230742   3.124249
# 2020       0.027177        65 -5.033238  11.322070
# All        0.097970       482 -5.967293  11.322070

# %%
# Out:
#               mean     count
#          Proft1000 Proft1000
# 10:45:00  2.740797         5
# 11:45:00  0.561842         5
# 12:45:00  0.632109        28
# 13:45:00  0.471562       105
# All       0.585498       143
#               mean     count
#          Proft1300 Proft1300
# 10:45:00  2.614796         5
# 11:45:00  0.363369         5
# 12:45:00  0.706022        28
# 13:45:00  0.571994       105
# All       0.662369       143
#               mean     count
#          Proft1830 Proft1830
# 10:45:00  3.314291         5
# 11:45:00  0.255331         5
# 12:45:00  0.510192        28
# 13:45:00  0.545417       105
# All       0.625191       143
#               mean     count
#          ProftLaBa ProftLaBa
# 10:45:00  2.543375         5
# 11:45:00  0.173363         5
# 12:45:00  0.480153        28
# 13:45:00  0.573578       105
# All       0.610166       143

# %%
# Out:
#                mean     count
#           Proft1000 Proft1000
# date_time
# 2010       0.516307        40
# 2011       0.396233        62
# 2012       0.458228        23
# 2013       0.583476        19
# 2014       0.560509        43
# 2015       0.334464        63
# 2016       0.573455        39
# 2017       0.276000        38
# 2018       0.573587        12
# All        0.447649       339
#                mean     count
#           Proft1300 Proft1300
# date_time
# 2010       0.559504        40
# 2011       0.337822        62
# 2012       0.504631        23
# 2013       0.459407        19
# 2014       0.922171        43
# 2015       0.348676        63
# 2016       0.682813        39
# 2017       0.280488        38
# 2018       0.554143        12
# All        0.499169       339
#                mean     count
#           Proft1830 Proft1830
# date_time
# 2010       0.567953        40
# 2011       0.561916        62
# 2012       0.579721        23
# 2013       0.455690        19
# 2014       0.802708        43
# 2015       0.353599        63
# 2016       0.785053        39
# 2017       0.275375        38
# 2018       0.686680        12
# All        0.547679       339
#                mean     count
#           ProftLaBa ProftLaBa
# date_time
# 2010       0.487267        40
# 2011       0.458407        62
# 2012       0.475487        23
# 2013       0.495439        19
# 2014       0.788865        43
# 2015       0.447673        63
# 2016       0.646613        39
# 2017       0.297090        38
# 2018       0.522884        12
# All        0.510820       339

# %%
# Out:
#                             count                   mean          \
#                    Profit_carrent Target_ Profit_carrent Target_
# Target    from_
# Proft1000 10:45:00             45      45           0.87    0.44
#           11:45:00             79      79           0.42    0.52
#           12:45:00             58      58           0.38    0.57
#           13:45:00            142     142           0.48    0.50
#           14:45:00             21      21          -0.24    0.48
#           15:45:00            162     162           0.45    0.46
#           16:45:00             18      18          -0.34    0.50
# Proft1300 10:45:00             45      45           0.94    0.44
#           11:45:00             79      79           0.56    0.52
#           12:45:00             58      58           0.11    0.57
#           13:45:00            142     142           0.68    0.50
#           14:45:00             21      21           0.10    0.48
#           15:45:00            162     162           0.48    0.46
#           16:45:00             18      18          -0.32    0.50
# ProftLaBa 10:45:00             45      45           0.04    0.44
#           11:45:00             79      79           0.32    0.52
#           12:45:00             58      58          -0.14    0.57
#           13:45:00            142     142           0.10    0.50
#           14:45:00             21      21          -0.71    0.48
#           15:45:00            162     162           0.19    0.46
#           16:45:00             18      18          -0.38    0.50
# All                          1575    1575           0.34    0.49
#
#                             count                   mean
#                    Profit_carrent Target_ Profit_carrent Target_
# Target    from_
# Proft1000 10:45:00          12307   12307           0.02    0.39
#           11:45:00          12273   12273           0.03    0.39
#           12:45:00          12294   12294           0.04    0.39
#           13:45:00          12210   12210           0.04    0.39
#           14:45:00          12331   12331           0.05    0.39
#           15:45:00          12190   12190           0.04    0.38
#           16:45:00          12334   12334           0.05    0.38
# Proft1300 10:45:00          12307   12307           0.01    0.39
#           11:45:00          12273   12273           0.02    0.39
#           12:45:00          12294   12294           0.03    0.39
#           13:45:00          12210   12210           0.03    0.39
#           14:45:00          12331   12331           0.03    0.39
#           15:45:00          12190   12190           0.02    0.38
#           16:45:00          12334   12334           0.03    0.38
# ProftLaBa 10:45:00          12307   12307           0.01    0.39
#           11:45:00          12273   12273           0.02    0.39
#           12:45:00          12294   12294           0.03    0.39
#           13:45:00          12210   12210           0.03    0.39
#           14:45:00          12331   12331           0.03    0.39
#           15:45:00          12190   12190           0.02    0.38
#           16:45:00          12334   12334           0.03    0.38
# All                        257817  257817           0.03    0.39

# %%
from_  = '10:45:00'
Target = 'Proft1300'
varP = 0.5
ss      = pd.pivot_table(matrix_year[(matrix_year['2proba']>=varP) & (matrix_year['from_'] == from_) & (matrix_year['Target']==Target)]
                         , values=['Profit_carrent'], index=['Date'], aggfunc=['mean', 'count'])

ss.columns = ['mean', 'count']
display(ss.shape)

from_  = '11:45:00'
#Target = 'Proft1000'

ss1      = pd.pivot_table(matrix_year[(matrix_year['2proba']>=varP) & (matrix_year['from_'] == from_) & (matrix_year['Target']==Target)]
                         , values=['Profit_carrent'], index=['Date'], aggfunc=['mean', 'count'])

ss1.columns = ['mean', 'count']
display(ss1.shape)

from_  = '11:45:00'
#Target = 'Proft1000'

ss2      = pd.pivot_table(matrix_year[(matrix_year['2proba']>=varP) & (matrix_year['from_'] == from_) & (matrix_year['Target']==Target)]
                         , values=['Profit_carrent'], index=['Date'], aggfunc=['mean', 'count'])

ss2.columns = ['mean', 'count']
display(ss2.shape)

all = pd.merge(ss,  ss1, on = 'Date', how='outer')
#display(all)
display(all.shape)
all = pd.merge(all, ss2, on = 'Date', how='outer')
all.sort_index(inplace=True)
display(all.shape)
all.columns = ['13:45:00mean', 'count','14:45:00mean', 'count','15:45:00mean', 'count',]

all['mean'] = all['13:45:00mean'].fillna(all['14:45:00mean']).fillna(all['15:45:00mean'])
all

all_pivo1    = pd.pivot_table(all, index=all.index.year, values=['13:45:00mean'], aggfunc=['mean', 'count'], margins=True)
all_pivo2    = pd.pivot_table(all, index=all.index.year, values=['14:45:00mean'], aggfunc=['mean', 'count'], margins=True)
all_pivo3    = pd.pivot_table(all, index=all.index.year, values=['15:45:00mean'], aggfunc=['mean', 'count'], margins=True)
all_pivo4    = pd.pivot_table(all, index=all.index.year, values=['mean']  , aggfunc=['mean', 'count'], margins=True)

all_pivo     = pd.concat([all_pivo1,all_pivo2,all_pivo3,all_pivo4], axis=1)
all_pivo.columns = ['13:45:00mean', 'count', '14:45:00mean', 'count','15:45:00mean', 'count','MEAN', 'COUNT',]

#all_pivo.sort_index(inplace=True)
all_pivo
# Out:
# (27, 2)
# (25, 2)
# (25, 2)
# (38, 4)
# (38, 6)
#       13:45:00mean  count  14:45:00mean  count  15:45:00mean  count      MEAN  \
# 2010      0.932213      7      3.386022      3      3.386022      3  1.016830
# 2011      0.532963      9      1.977596      8      1.977596      8  0.604435
# 2012      5.604518      1      2.020839      1      2.020839      1  5.604518
# 2013     -1.223559      1     -0.272194      1     -0.272194      1 -1.223559
# 2014      1.129706      5      1.103454     10      1.103454     10  1.111829
# 2015     -0.952231      3           NaN      0           NaN      0 -0.952231
# 2016      2.969822      1      3.580067      1      3.580067      1  2.969822
# All       0.794992     27      1.579472     25      1.579472     25  0.756563
# 2017           NaN      0     -2.855279      1     -2.855279      1 -2.855279
#
#       COUNT
# 2010      8
# 2011     13
# 2012      1
# 2013      1
# 2014     10
# 2015      3
# 2016      1
# All      38
# 2017      1

# %%
from_  = '13:45:00'
Target = 'Proft1000'
varP = 0.5

ss      = pd.pivot_table(matrix_year[(matrix_year['2proba']>=varP) & (matrix_year['from_'] == from_) & (matrix_year['Target']==Target)]
                         , values=['Profit_carrent'], index=['Date'], aggfunc=['mean', 'count'])

ss.columns = ['mean', 'count']
ss
ss_next = pd.pivot_table(ss, values=['mean'], index=ss.index.year, aggfunc=['mean', 'count'], margins=True)
display(ss_next)
# ss.to_excel('sss.xlsx')
ss_comp = pd.pivot_table(matrix_year[(matrix_year['2proba']>=varP) & (matrix_year['from_'] == from_) & (matrix_year['Target']==Target)], 
                         values=['Profit_carrent'], index=['Year'], aggfunc=['mean', 'count'], margins=True)
ss_comp
# Out:
#           mean count
#           mean  mean
# Date
# 2010  0.450845    34
# 2011  0.693576    38
# 2012  0.263599    16
# 2013  0.619770    11
# 2014  0.718972    44
# 2015  0.459171    34
# 2016  0.717551    27
# 2017  0.123885    13
# 2018  1.059297     9
# All   0.577364   226
#                mean          count
#      Profit_carrent Profit_carrent
# Year
# 2010       0.542626             48
# 2011       0.889472             62
# 2012       0.116372             22
# 2013       0.508389             12
# 2014       0.637720             76
# 2015       0.306850             72
# 2016       0.717516             35
# 2017       0.243350             16
# 2018       1.059297              9
# All        0.565211            352

# %%
pd.options.display.max_rows=2000
all = ['from_', 'Target', ]
result_(0.525,0.525)
# Out:
#                             count                   mean          \
#                    Profit_carrent Target_ Profit_carrent Target_
# from_    Target
# 10:45:00 Pro_Morni            317     317           0.23    0.54
#          Profi_GEP           9594    9594           0.05    0.55
#          Proft1000           4406    4406           0.10    0.52
#          Proft1300           3392    3392          -0.00    0.52
#          Proft1830           3548    3548          -0.02    0.50
#          ProftLaBa           1344    1344           0.03    0.50
# 12:45:00 Pro_Morni             80      80          -0.39    0.51
#          Profi_GEP          10399   10399           0.08    0.55
#          Proft1000           5782    5782           0.22    0.55
#          Proft1300           4229    4229           0.18    0.53
#          Proft1830           3395    3395           0.19    0.53
#          ProftLaBa           3209    3209           0.16    0.53
# 14:45:00 Pro_Morni             63      63          -1.28    0.37
#          Profi_GEP          10979   10979           0.08    0.54
#          Proft1000           9040    9040           0.21    0.55
#          Proft1300           5891    5891           0.23    0.54
#          Proft1830           5552    5552           0.16    0.52
#          ProftLaBa           7151    7151           0.10    0.53
# 16:45:00 Pro_Morni            258     258          -0.12    0.50
#          Profi_GEP           9977    9977           0.10    0.55
#          Proft1000           7872    7872           0.21    0.55
#          Proft1300           5304    5304           0.23    0.54
#          Proft1830           2554    2554           0.13    0.51
#          ProftLaBa           4530    4530           0.11    0.55
# All                        118866  118866           0.13    0.54
#
#                             count                   mean
#                    Profit_carrent Target_ Profit_carrent Target_
# from_    Target
# 10:45:00 Pro_Morni           8213    8213          -0.03    0.48
#          Profi_GEP             12      12           0.40    0.58
#          Proft1000           4061    4061           0.01    0.47
#          Proft1300           4468    4468          -0.03    0.47
#          Proft1830           3207    3207           0.01    0.47
#          ProftLaBa           5669    5669           0.03    0.48
# 12:45:00 Pro_Morni           7119    7119          -0.01    0.48
#          Profi_GEP            158     158           0.31    0.53
#          Proft1000           1710    1710          -0.08    0.45
#          Proft1300           2126    2126          -0.13    0.46
#          Proft1830           1203    1203           0.17    0.50
#          ProftLaBa           5971    5971          -0.03    0.48
# 14:45:00 Pro_Morni           6893    6893           0.00    0.49
#          Profi_GEP            128     128          -0.80    0.55
#          Proft1000            814     814          -0.28    0.44
#          Proft1300            849     849          -0.14    0.47
#          Proft1830           1339    1339          -0.16    0.46
#          ProftLaBa           2307    2307          -0.10    0.47
# 16:45:00 Pro_Morni           9480    9480          -0.03    0.48
#          Profi_GEP            329     329          -0.50    0.52
#          Proft1000            251     251          -1.04    0.52
#          Proft1300            283     283          -0.29    0.47
#          Proft1830            140     140           0.72    0.54
#          ProftLaBa           5255    5255          -0.05    0.48
# All                         71985   71985          -0.03    0.48

# %%
feat_importances
# Out:
#                         0      1                     0      1  \
# 0              Cl/min_day  0.021            Cl/min_day  0.039
# 1              Cl/max_day  0.003            Cl/max_day  0.002
# 2         max_day-min_day  0.000       max_day-min_day  0.000
# 3                   ADX_5  0.006                 ADX_5  0.003
# 4                  ADX_14  0.006                ADX_14  0.004
# 5                  ADX_28  0.000                ADX_28  0.000
# 6                  ADXR_5  0.005                ADXR_5  0.007
# 7                 ADXR_14  0.000               ADXR_14  0.008
# 8                 ADXR_28  0.005               ADXR_28  0.015
# 9                   APO_5  0.002                 APO_5  0.000
# 10                 APO_14  0.031                APO_14  0.013
# 11                 APO_28  0.003                APO_28  0.006
# 12             AROONOSC_5  0.000            AROONOSC_5  0.000
# 13            AROONOSC_14  0.005           AROONOSC_14  0.000
# 14            AROONOSC_28  0.009           AROONOSC_28  0.016
# 15                  BOP_5  0.003                 BOP_5  0.010
# 16                 BOP_14  0.022                BOP_14  0.022
# 17                 BOP_28  0.027                BOP_28  0.016
# 18                  CCI_5  0.010                 CCI_5  0.011
# 19                 CCI_14  0.022                CCI_14  0.010
# 20                 CCI_28  0.010                CCI_28  0.000
# 21                  CMO_5  0.002                 CMO_5  0.003
# 22                 CMO_14  0.000                CMO_14  0.000
# 23                 CMO_28  0.002                CMO_28  0.003
# 24                   DX_5  0.000                  DX_5  0.006
# 25                  DX_14  0.008                 DX_14  0.002
# 26                  DX_28  0.004                 DX_28  0.000
# 27                  MFI_5  0.002                 MFI_5  0.003
# 28                 MFI_14  0.007                MFI_14  0.011
# 29                 MFI_28  0.021                MFI_28  0.006
# 30             MINUS_DI_5  0.000            MINUS_DI_5  0.004
# 31            MINUS_DI_14  0.012           MINUS_DI_14  0.008
# 32            MINUS_DI_28  0.000           MINUS_DI_28  0.000
# 33             MINUS_DM_5  0.000            MINUS_DM_5  0.006
# 34            MINUS_DM_14  0.004           MINUS_DM_14  0.001
# 35            MINUS_DM_28  0.006           MINUS_DM_28  0.002
# 36                  MOM_5  0.000                 MOM_5  0.000
# 37                 MOM_14  0.000                MOM_14  0.000
# 38                 MOM_28  0.004                MOM_28  0.000
# 39              PLUS_DI_5  0.000             PLUS_DI_5  0.003
# 40             PLUS_DI_14  0.019            PLUS_DI_14  0.013
# 41             PLUS_DI_28  0.016            PLUS_DI_28  0.048
# 42              PLUS_DM_5  0.000             PLUS_DM_5  0.000
# 43             PLUS_DM_14  0.009            PLUS_DM_14  0.000
# 44             PLUS_DM_28  0.000            PLUS_DM_28  0.000
# 45                  PPO_5  0.003                 PPO_5  0.007
# 46                 PPO_14  0.014                PPO_14  0.022
# 47                 PPO_28  0.028                PPO_28  0.034
# 48                  ROC_5  0.000                 ROC_5  0.000
# 49                 ROC_14  0.004                ROC_14  0.000
# 50                 ROC_28  0.033                ROC_28  0.044
# 51                 ROCP_5  0.006                ROCP_5  0.000
# 52                ROCP_14  0.000               ROCP_14  0.002
# 53                ROCP_28  0.017               ROCP_28  0.023
# 54                 ROCR_5  0.004                ROCR_5  0.000
# 55                ROCR_14  0.006               ROCR_14  0.006
# 56                ROCR_28  0.009               ROCR_28  0.030
# 57              ROCR100_5  0.000             ROCR100_5  0.000
# 58             ROCR100_14  0.006            ROCR100_14  0.004
# 59             ROCR100_28  0.014            ROCR100_28  0.028
# 60                  RSI_5  0.003                 RSI_5  0.000
# 61                 RSI_14  0.003                RSI_14  0.000
# 62                 RSI_28  0.003                RSI_28  0.003
# 63                 TRIX_5  0.012                TRIX_5  0.000
# 64                TRIX_14  0.015               TRIX_14  0.009
# 65                TRIX_28  0.002               TRIX_28  0.011
# 66               ULTOSC_5  0.006              ULTOSC_5  0.002
# 67              ULTOSC_14  0.003             ULTOSC_14  0.004
# 68              ULTOSC_28  0.003             ULTOSC_28  0.001
# 69                WILLR_5  0.010               WILLR_5  0.005
# 70               WILLR_14  0.025              WILLR_14  0.023
# 71               WILLR_28  0.015              WILLR_28  0.016
# 72          HT_DCPERIOD_5  0.016         HT_DCPERIOD_5  0.014
# 73         HT_DCPERIOD_14  0.013        HT_DCPERIOD_14  0.020
# 74         HT_DCPERIOD_28  0.000        HT_DCPERIOD_28  0.022
# 75           HT_DCPHASE_5  0.010          HT_DCPHASE_5  0.008
# 76          HT_DCPHASE_14  0.008         HT_DCPHASE_14  0.016
# 77          HT_DCPHASE_28  0.017         HT_DCPHASE_28  0.011
# 78         HT_TRENDMODE_5  0.000        HT_TRENDMODE_5  0.000
# 79        HT_TRENDMODE_14  0.000       HT_TRENDMODE_14  0.000
# 80        HT_TRENDMODE_28  0.000       HT_TRENDMODE_28  0.000
# 81                 DEMA_5  0.012                DEMA_5  0.009
# 82                DEMA_14  0.001               DEMA_14  0.004
# 83                DEMA_28  0.000               DEMA_28  0.004
# 84                  EMA_5  0.000                 EMA_5  0.000
# 85                 EMA_14  0.000                EMA_14  0.004
# 86                 EMA_28  0.002                EMA_28  0.005
# 87         HT_TRENDLINE_5  0.000        HT_TRENDLINE_5  0.002
# 88        HT_TRENDLINE_14  0.000       HT_TRENDLINE_14  0.003
# 89        HT_TRENDLINE_28  0.010       HT_TRENDLINE_28  0.003
# 90                 KAMA_5  0.004                KAMA_5  0.000
# 91                KAMA_14  0.012               KAMA_14  0.005
# 92                KAMA_28  0.006               KAMA_28  0.011
# 93                   MA_5  0.004                  MA_5  0.000
# 94                  MA_14  0.000                 MA_14  0.000
# 95                  MA_28  0.000                 MA_28  0.004
# 96             MIDPOINT_5  0.004            MIDPOINT_5  0.000
# 97            MIDPOINT_14  0.000           MIDPOINT_14  0.002
# 98            MIDPOINT_28  0.006           MIDPOINT_28  0.009
# 99             MIDPRICE_5  0.002            MIDPRICE_5  0.005
# 100           MIDPRICE_14  0.002           MIDPRICE_14  0.005
# 101           MIDPRICE_28  0.000           MIDPRICE_28  0.004
# 102                 SMA_5  0.000                 SMA_5  0.003
# 103                SMA_14  0.000                SMA_14  0.000
# 104                SMA_28  0.000                SMA_28  0.009
# 105                  T3_5  0.000                  T3_5  0.003
# 106                 T3_14  0.004                 T3_14  0.005
# 107                 T3_28  0.010                 T3_28  0.012
# 108                TEMA_5  0.011                TEMA_5  0.002
# 109               TEMA_14  0.005               TEMA_14  0.006
# 110               TEMA_28  0.004               TEMA_28  0.006
# 111               TRIMA_5  0.005               TRIMA_5  0.003
# 112              TRIMA_14  0.000              TRIMA_14  0.000
# 113              TRIMA_28  0.010              TRIMA_28  0.008
# 114                 WMA_5  0.004                 WMA_5  0.008
# 115                WMA_14  0.003                WMA_14  0.000
# 116                WMA_28  0.004                WMA_28  0.003
# 117                 ATR_5  0.000                 ATR_5  0.001
# 118                ATR_14  0.002                ATR_14  0.002
# 119                ATR_28  0.010                ATR_28  0.000
# 120                NATR_5  0.000                NATR_5  0.000
# 121               NATR_14  0.000               NATR_14  0.002
# 122               NATR_28  0.000               NATR_28  0.000
# 123              TRANGE_5  0.000              TRANGE_5  0.006
# 124             TRANGE_14  0.005             TRANGE_14  0.000
# 125             TRANGE_28  0.004             TRANGE_28  0.002
# 126                  AD_5  0.008                  AD_5  0.004
# 127                 AD_14  0.006                 AD_14  0.003
# 128                 AD_28  0.011                 AD_28  0.000
# 129               ADOSC_5  0.000               ADOSC_5  0.004
# 130              ADOSC_14  0.000              ADOSC_14  0.002
# 131              ADOSC_28  0.000              ADOSC_28  0.000
# 132                 OBV_5  0.005                 OBV_5  0.005
# 133                OBV_14  0.000                OBV_14  0.000
# 134                OBV_28  0.008                OBV_28  0.012
# 135       AROON_aroondown  0.005       AROON_aroondown  0.000
# 136         AROON_aroonup  0.000         AROON_aroonup  0.003
# 137             MACD_macd  0.003             MACD_macd  0.000
# 138       MACD_macdsignal  0.018       MACD_macdsignal  0.010
# 139         MACD_macdhist  0.000         MACD_macdhist  0.003
# 140          MACDEXT_macd  0.003          MACDEXT_macd  0.000
# 141    MACDEXT_macdsignal  0.012    MACDEXT_macdsignal  0.008
# 142      MACDEXT_macdhist  0.002      MACDEXT_macdhist  0.000
# 143          MACDFIX_macd  0.004          MACDFIX_macd  0.002
# 144    MACDFIX_macdsignal  0.035    MACDFIX_macdsignal  0.022
# 145      MACDFIX_macdhist  0.000      MACDFIX_macdhist  0.000
# 146           STOCH_slowk  0.003           STOCH_slowk  0.004
# 147           STOCH_slowd  0.000           STOCH_slowd  0.000
# 148          STOCHF_fastk  0.016          STOCHF_fastk  0.006
# 149          STOCHF_fastd  0.000          STOCHF_fastd  0.000
# 150        STOCHRSI_fastk  0.002        STOCHRSI_fastk  0.000
# 151        STOCHRSI_fastd  0.002        STOCHRSI_fastd  0.002
# 152     HT_PHASOR_inphase  0.000     HT_PHASOR_inphase  0.000
# 153  HT_PHASOR_quadrature  0.004  HT_PHASOR_quadrature  0.007
# 154          HT_SINE_sine  0.009          HT_SINE_sine  0.007
# 155      HT_SINE_leadsine  0.006      HT_SINE_leadsine  0.012
# 156      BBANDS_upperband  0.005      BBANDS_upperband  0.000
# 157     BBANDS_middleband  0.005     BBANDS_middleband  0.000
# 158      BBANDS_lowerband  0.000      BBANDS_lowerband  0.000
# 159             MAMA_mama  0.005             MAMA_mama  0.006
# 160             MAMA_fama  0.015             MAMA_fama  0.003
# 161                 Min10  0.000                 Min10  0.007
# 162               Min1000  0.016               Min1000  0.020
# 163            Min10_1300  0.009            Min10_1300  0.000
# 164            Min10_1000  0.020            Min10_1000  0.019
#
#                         0      1                     0      1  \
# 0              Cl/min_day  0.028            Cl/min_day  0.023
# 1              Cl/max_day  0.006            Cl/max_day  0.004
# 2         max_day-min_day  0.004       max_day-min_day  0.009
# 3                   ADX_5  0.000                 ADX_5  0.005
# 4                  ADX_14  0.000                ADX_14  0.014
# 5                  ADX_28  0.000                ADX_28  0.005
# 6                  ADXR_5  0.003                ADXR_5  0.002
# 7                 ADXR_14  0.002               ADXR_14  0.002
# 8                 ADXR_28  0.000               ADXR_28  0.003
# 9                   APO_5  0.000                 APO_5  0.007
# 10                 APO_14  0.017                APO_14  0.018
# 11                 APO_28  0.005                APO_28  0.000
# 12             AROONOSC_5  0.004            AROONOSC_5  0.000
# 13            AROONOSC_14  0.000           AROONOSC_14  0.000
# 14            AROONOSC_28  0.000           AROONOSC_28  0.005
# 15                  BOP_5  0.023                 BOP_5  0.018
# 16                 BOP_14  0.050                BOP_14  0.022
# 17                 BOP_28  0.021                BOP_28  0.006
# 18                  CCI_5  0.015                 CCI_5  0.018
# 19                 CCI_14  0.021                CCI_14  0.017
# 20                 CCI_28  0.007                CCI_28  0.004
# 21                  CMO_5  0.014                 CMO_5  0.004
# 22                 CMO_14  0.004                CMO_14  0.000
# 23                 CMO_28  0.004                CMO_28  0.006
# 24                   DX_5  0.000                  DX_5  0.015
# 25                  DX_14  0.002                 DX_14  0.008
# 26                  DX_28  0.007                 DX_28  0.004
# 27                  MFI_5  0.000                 MFI_5  0.000
# 28                 MFI_14  0.000                MFI_14  0.008
# 29                 MFI_28  0.005                MFI_28  0.007
# 30             MINUS_DI_5  0.003            MINUS_DI_5  0.005
# 31            MINUS_DI_14  0.000           MINUS_DI_14  0.007
# 32            MINUS_DI_28  0.004           MINUS_DI_28  0.006
# 33             MINUS_DM_5  0.000            MINUS_DM_5  0.000
# 34            MINUS_DM_14  0.003           MINUS_DM_14  0.000
# 35            MINUS_DM_28  0.004           MINUS_DM_28  0.002
# 36                  MOM_5  0.004                 MOM_5  0.004
# 37                 MOM_14  0.000                MOM_14  0.000
# 38                 MOM_28  0.008                MOM_28  0.003
# 39              PLUS_DI_5  0.010             PLUS_DI_5  0.007
# 40             PLUS_DI_14  0.034            PLUS_DI_14  0.013
# 41             PLUS_DI_28  0.014            PLUS_DI_28  0.028
# 42              PLUS_DM_5  0.006             PLUS_DM_5  0.005
# 43             PLUS_DM_14  0.000            PLUS_DM_14  0.005
# 44             PLUS_DM_28  0.003            PLUS_DM_28  0.000
# 45                  PPO_5  0.008                 PPO_5  0.014
# 46                 PPO_14  0.017                PPO_14  0.016
# 47                 PPO_28  0.026                PPO_28  0.020
# 48                  ROC_5  0.004                 ROC_5  0.009
# 49                 ROC_14  0.002                ROC_14  0.005
# 50                 ROC_28  0.013                ROC_28  0.024
# 51                 ROCP_5  0.000                ROCP_5  0.003
# 52                ROCP_14  0.002               ROCP_14  0.004
# 53                ROCP_28  0.020               ROCP_28  0.026
# 54                 ROCR_5  0.000                ROCR_5  0.003
# 55                ROCR_14  0.001               ROCR_14  0.002
# 56                ROCR_28  0.018               ROCR_28  0.032
# 57              ROCR100_5  0.000             ROCR100_5  0.003
# 58             ROCR100_14  0.003            ROCR100_14  0.000
# 59             ROCR100_28  0.027            ROCR100_28  0.020
# 60                  RSI_5  0.002                 RSI_5  0.005
# 61                 RSI_14  0.007                RSI_14  0.008
# 62                 RSI_28  0.003                RSI_28  0.000
# 63                 TRIX_5  0.003                TRIX_5  0.007
# 64                TRIX_14  0.007               TRIX_14  0.006
# 65                TRIX_28  0.005               TRIX_28  0.015
# 66               ULTOSC_5  0.002              ULTOSC_5  0.003
# 67              ULTOSC_14  0.005             ULTOSC_14  0.000
# 68              ULTOSC_28  0.006             ULTOSC_28  0.015
# 69                WILLR_5  0.010               WILLR_5  0.009
# 70               WILLR_14  0.012              WILLR_14  0.010
# 71               WILLR_28  0.007              WILLR_28  0.008
# 72          HT_DCPERIOD_5  0.019         HT_DCPERIOD_5  0.010
# 73         HT_DCPERIOD_14  0.018        HT_DCPERIOD_14  0.008
# 74         HT_DCPERIOD_28  0.025        HT_DCPERIOD_28  0.002
# 75           HT_DCPHASE_5  0.002          HT_DCPHASE_5  0.013
# 76          HT_DCPHASE_14  0.007         HT_DCPHASE_14  0.011
# 77          HT_DCPHASE_28  0.000         HT_DCPHASE_28  0.007
# 78         HT_TRENDMODE_5  0.000        HT_TRENDMODE_5  0.000
# 79        HT_TRENDMODE_14  0.000       HT_TRENDMODE_14  0.000
# 80        HT_TRENDMODE_28  0.000       HT_TRENDMODE_28  0.000
# 81                 DEMA_5  0.000                DEMA_5  0.005
# 82                DEMA_14  0.000               DEMA_14  0.003
# 83                DEMA_28  0.000               DEMA_28  0.000
# 84                  EMA_5  0.003                 EMA_5  0.000
# 85                 EMA_14  0.000                EMA_14  0.000
# 86                 EMA_28  0.007                EMA_28  0.004
# 87         HT_TRENDLINE_5  0.004        HT_TRENDLINE_5  0.004
# 88        HT_TRENDLINE_14  0.000       HT_TRENDLINE_14  0.000
# 89        HT_TRENDLINE_28  0.002       HT_TRENDLINE_28  0.005
# 90                 KAMA_5  0.005                KAMA_5  0.000
# 91                KAMA_14  0.011               KAMA_14  0.003
# 92                KAMA_28  0.008               KAMA_28  0.013
# 93                   MA_5  0.000                  MA_5  0.007
# 94                  MA_14  0.000                 MA_14  0.002
# 95                  MA_28  0.000                 MA_28  0.004
# 96             MIDPOINT_5  0.000            MIDPOINT_5  0.000
# 97            MIDPOINT_14  0.005           MIDPOINT_14  0.000
# 98            MIDPOINT_28  0.006           MIDPOINT_28  0.008
# 99             MIDPRICE_5  0.003            MIDPRICE_5  0.000
# 100           MIDPRICE_14  0.000           MIDPRICE_14  0.000
# 101           MIDPRICE_28  0.010           MIDPRICE_28  0.000
# 102                 SMA_5  0.000                 SMA_5  0.004
# 103                SMA_14  0.000                SMA_14  0.000
# 104                SMA_28  0.006                SMA_28  0.000
# 105                  T3_5  0.004                  T3_5  0.002
# 106                 T3_14  0.000                 T3_14  0.012
# 107                 T3_28  0.009                 T3_28  0.004
# 108                TEMA_5  0.013                TEMA_5  0.003
# 109               TEMA_14  0.000               TEMA_14  0.000
# 110               TEMA_28  0.010               TEMA_28  0.006
# 111               TRIMA_5  0.003               TRIMA_5  0.002
# 112              TRIMA_14  0.000              TRIMA_14  0.003
# 113              TRIMA_28  0.003              TRIMA_28  0.006
# 114                 WMA_5  0.002                 WMA_5  0.000
# 115                WMA_14  0.002                WMA_14  0.000
# 116                WMA_28  0.000                WMA_28  0.002
# 117                 ATR_5  0.000                 ATR_5  0.002
# 118                ATR_14  0.000                ATR_14  0.003
# 119                ATR_28  0.000                ATR_28  0.005
# 120                NATR_5  0.000                NATR_5  0.003
# 121               NATR_14  0.000               NATR_14  0.000
# 122               NATR_28  0.000               NATR_28  0.002
# 123              TRANGE_5  0.000              TRANGE_5  0.003
# 124             TRANGE_14  0.000             TRANGE_14  0.002
# 125             TRANGE_28  0.000             TRANGE_28  0.002
# 126                  AD_5  0.007                  AD_5  0.002
# 127                 AD_14  0.003                 AD_14  0.000
# 128                 AD_28  0.007                 AD_28  0.002
# 129               ADOSC_5  0.003               ADOSC_5  0.003
# 130              ADOSC_14  0.000              ADOSC_14  0.000
# 131              ADOSC_28  0.011              ADOSC_28  0.000
# 132                 OBV_5  0.008                 OBV_5  0.004
# 133                OBV_14  0.003                OBV_14  0.000
# 134                OBV_28  0.010                OBV_28  0.006
# 135       AROON_aroondown  0.007       AROON_aroondown  0.000
# 136         AROON_aroonup  0.003         AROON_aroonup  0.004
# 137             MACD_macd  0.000             MACD_macd  0.004
# 138       MACD_macdsignal  0.018       MACD_macdsignal  0.013
# 139         MACD_macdhist  0.002         MACD_macdhist  0.003
# 140          MACDEXT_macd  0.011          MACDEXT_macd  0.015
# 141    MACDEXT_macdsignal  0.018    MACDEXT_macdsignal  0.042
# 142      MACDEXT_macdhist  0.002      MACDEXT_macdhist  0.002
# 143          MACDFIX_macd  0.004          MACDFIX_macd  0.002
# 144    MACDFIX_macdsignal  0.031    MACDFIX_macdsignal  0.014
# 145      MACDFIX_macdhist  0.000      MACDFIX_macdhist  0.000
# 146           STOCH_slowk  0.005           STOCH_slowk  0.006
# 147           STOCH_slowd  0.000           STOCH_slowd  0.000
# 148          STOCHF_fastk  0.004          STOCHF_fastk  0.012
# 149          STOCHF_fastd  0.000          STOCHF_fastd  0.007
# 150        STOCHRSI_fastk  0.002        STOCHRSI_fastk  0.000
# 151        STOCHRSI_fastd  0.004        STOCHRSI_fastd  0.000
# 152     HT_PHASOR_inphase  0.000     HT_PHASOR_inphase  0.002
# 153  HT_PHASOR_quadrature  0.010  HT_PHASOR_quadrature  0.014
# 154          HT_SINE_sine  0.006          HT_SINE_sine  0.006
# 155      HT_SINE_leadsine  0.003      HT_SINE_leadsine  0.007
# 156      BBANDS_upperband  0.005      BBANDS_upperband  0.003
# 157     BBANDS_middleband  0.007     BBANDS_middleband  0.011
# 158      BBANDS_lowerband  0.003      BBANDS_lowerband  0.000
# 159             MAMA_mama  0.003             MAMA_mama  0.000
# 160             MAMA_fama  0.004             MAMA_fama  0.004
# 161                 Min10  0.003                 Min10  0.007
# 162               Min1000  0.027               Min1000  0.025
# 163            Min10_1300  0.004            Min10_1300  0.000
# 164            Min10_1000  0.033            Min10_1000  0.015
#
#                         0      1  ...                     0      1  \
# 0              Cl/min_day  0.031  ...            Cl/min_day  0.008
# 1              Cl/max_day  0.000  ...            Cl/max_day  0.010
# 2         max_day-min_day  0.006  ...       max_day-min_day  0.006
# 3                   ADX_5  0.000  ...                 ADX_5  0.008
# 4                  ADX_14  0.014  ...                ADX_14  0.000
# 5                  ADX_28  0.003  ...                ADX_28  0.000
# 6                  ADXR_5  0.000  ...                ADXR_5  0.003
# 7                 ADXR_14  0.009  ...               ADXR_14  0.004
# 8                 ADXR_28  0.004  ...               ADXR_28  0.000
# 9                   APO_5  0.000  ...                 APO_5  0.007
# 10                 APO_14  0.012  ...                APO_14  0.000
# 11                 APO_28  0.000  ...                APO_28  0.011
# 12             AROONOSC_5  0.000  ...            AROONOSC_5  0.000
# 13            AROONOSC_14  0.001  ...           AROONOSC_14  0.003
# 14            AROONOSC_28  0.006  ...           AROONOSC_28  0.007
# 15                  BOP_5  0.005  ...                 BOP_5  0.015
# 16                 BOP_14  0.012  ...                BOP_14  0.012
# 17                 BOP_28  0.011  ...                BOP_28  0.008
# 18                  CCI_5  0.000  ...                 CCI_5  0.000
# 19                 CCI_14  0.010  ...                CCI_14  0.022
# 20                 CCI_28  0.014  ...                CCI_28  0.003
# 21                  CMO_5  0.003  ...                 CMO_5  0.001
# 22                 CMO_14  0.000  ...                CMO_14  0.003
# 23                 CMO_28  0.003  ...                CMO_28  0.012
# 24                   DX_5  0.006  ...                  DX_5  0.017
# 25                  DX_14  0.007  ...                 DX_14  0.003
# 26                  DX_28  0.017  ...                 DX_28  0.006
# 27                  MFI_5  0.000  ...                 MFI_5  0.000
# 28                 MFI_14  0.012  ...                MFI_14  0.000
# 29                 MFI_28  0.000  ...                MFI_28  0.000
# 30             MINUS_DI_5  0.000  ...            MINUS_DI_5  0.010
# 31            MINUS_DI_14  0.002  ...           MINUS_DI_14  0.005
# 32            MINUS_DI_28  0.006  ...           MINUS_DI_28  0.006
# 33             MINUS_DM_5  0.008  ...            MINUS_DM_5  0.003
# 34            MINUS_DM_14  0.000  ...           MINUS_DM_14  0.008
# 35            MINUS_DM_28  0.000  ...           MINUS_DM_28  0.002
# 36                  MOM_5  0.000  ...                 MOM_5  0.007
# 37                 MOM_14  0.004  ...                MOM_14  0.002
# 38                 MOM_28  0.000  ...                MOM_28  0.007
# 39              PLUS_DI_5  0.007  ...             PLUS_DI_5  0.000
# 40             PLUS_DI_14  0.013  ...            PLUS_DI_14  0.004
# 41             PLUS_DI_28  0.029  ...            PLUS_DI_28  0.002
# 42              PLUS_DM_5  0.000  ...             PLUS_DM_5  0.006
# 43             PLUS_DM_14  0.004  ...            PLUS_DM_14  0.010
# 44             PLUS_DM_28  0.001  ...            PLUS_DM_28  0.000
# 45                  PPO_5  0.007  ...                 PPO_5  0.000
# 46                 PPO_14  0.014  ...                PPO_14  0.019
# 47                 PPO_28  0.014  ...                PPO_28  0.000
# 48                  ROC_5  0.003  ...                 ROC_5  0.013
# 49                 ROC_14  0.000  ...                ROC_14  0.000
# 50                 ROC_28  0.022  ...                ROC_28  0.004
# 51                 ROCP_5  0.003  ...                ROCP_5  0.013
# 52                ROCP_14  0.007  ...               ROCP_14  0.000
# 53                ROCP_28  0.018  ...               ROCP_28  0.000
# 54                 ROCR_5  0.002  ...                ROCR_5  0.023
# 55                ROCR_14  0.006  ...               ROCR_14  0.000
# 56                ROCR_28  0.024  ...               ROCR_28  0.011
# 57              ROCR100_5  0.000  ...             ROCR100_5  0.007
# 58             ROCR100_14  0.013  ...            ROCR100_14  0.000
# 59             ROCR100_28  0.025  ...            ROCR100_28  0.008
# 60                  RSI_5  0.005  ...                 RSI_5  0.007
# 61                 RSI_14  0.004  ...                RSI_14  0.008
# 62                 RSI_28  0.008  ...                RSI_28  0.013
# 63                 TRIX_5  0.008  ...                TRIX_5  0.005
# 64                TRIX_14  0.016  ...               TRIX_14  0.005
# 65                TRIX_28  0.013  ...               TRIX_28  0.007
# 66               ULTOSC_5  0.000  ...              ULTOSC_5  0.021
# 67              ULTOSC_14  0.010  ...             ULTOSC_14  0.017
# 68              ULTOSC_28  0.007  ...             ULTOSC_28  0.019
# 69                WILLR_5  0.004  ...               WILLR_5  0.000
# 70               WILLR_14  0.006  ...              WILLR_14  0.006
# 71               WILLR_28  0.005  ...              WILLR_28  0.010
# 72          HT_DCPERIOD_5  0.007  ...         HT_DCPERIOD_5  0.007
# 73         HT_DCPERIOD_14  0.015  ...        HT_DCPERIOD_14  0.000
# 74         HT_DCPERIOD_28  0.011  ...        HT_DCPERIOD_28  0.002
# 75           HT_DCPHASE_5  0.000  ...          HT_DCPHASE_5  0.004
# 76          HT_DCPHASE_14  0.003  ...         HT_DCPHASE_14  0.005
# 77          HT_DCPHASE_28  0.002  ...         HT_DCPHASE_28  0.000
# 78         HT_TRENDMODE_5  0.000  ...        HT_TRENDMODE_5  0.000
# 79        HT_TRENDMODE_14  0.000  ...       HT_TRENDMODE_14  0.000
# 80        HT_TRENDMODE_28  0.003  ...       HT_TRENDMODE_28  0.000
# 81                 DEMA_5  0.004  ...                DEMA_5  0.011
# 82                DEMA_14  0.000  ...               DEMA_14  0.007
# 83                DEMA_28  0.000  ...               DEMA_28  0.003
# 84                  EMA_5  0.007  ...                 EMA_5  0.009
# 85                 EMA_14  0.000  ...                EMA_14  0.005
# 86                 EMA_28  0.006  ...                EMA_28  0.002
# 87         HT_TRENDLINE_5  0.000  ...        HT_TRENDLINE_5  0.002
# 88        HT_TRENDLINE_14  0.008  ...       HT_TRENDLINE_14  0.000
# 89        HT_TRENDLINE_28  0.003  ...       HT_TRENDLINE_28  0.007
# 90                 KAMA_5  0.000  ...                KAMA_5  0.034
# 91                KAMA_14  0.007  ...               KAMA_14  0.021
# 92                KAMA_28  0.011  ...               KAMA_28  0.008
# 93                   MA_5  0.006  ...                  MA_5  0.015
# 94                  MA_14  0.000  ...                 MA_14  0.000
# 95                  MA_28  0.007  ...                 MA_28  0.011
# 96             MIDPOINT_5  0.002  ...            MIDPOINT_5  0.010
# 97            MIDPOINT_14  0.004  ...           MIDPOINT_14  0.000
# 98            MIDPOINT_28  0.016  ...           MIDPOINT_28  0.003
# 99             MIDPRICE_5  0.000  ...            MIDPRICE_5  0.008
# 100           MIDPRICE_14  0.006  ...           MIDPRICE_14  0.004
# 101           MIDPRICE_28  0.003  ...           MIDPRICE_28  0.013
# 102                 SMA_5  0.000  ...                 SMA_5  0.003
# 103                SMA_14  0.000  ...                SMA_14  0.000
# 104                SMA_28  0.004  ...                SMA_28  0.008
# 105                  T3_5  0.006  ...                  T3_5  0.016
# 106                 T3_14  0.000  ...                 T3_14  0.005
# 107                 T3_28  0.008  ...                 T3_28  0.011
# 108                TEMA_5  0.007  ...                TEMA_5  0.007
# 109               TEMA_14  0.006  ...               TEMA_14  0.011
# 110               TEMA_28  0.000  ...               TEMA_28  0.004
# 111               TRIMA_5  0.006  ...               TRIMA_5  0.012
# 112              TRIMA_14  0.009  ...              TRIMA_14  0.000
# 113              TRIMA_28  0.006  ...              TRIMA_28  0.022
# 114                 WMA_5  0.008  ...                 WMA_5  0.013
# 115                WMA_14  0.000  ...                WMA_14  0.000
# 116                WMA_28  0.012  ...                WMA_28  0.024
# 117                 ATR_5  0.009  ...                 ATR_5  0.020
# 118                ATR_14  0.008  ...                ATR_14  0.003
# 119                ATR_28  0.011  ...                ATR_28  0.002
# 120                NATR_5  0.000  ...                NATR_5  0.002
# 121               NATR_14  0.002  ...               NATR_14  0.000
# 122               NATR_28  0.003  ...               NATR_28  0.000
# 123              TRANGE_5  0.003  ...              TRANGE_5  0.003
# 124             TRANGE_14  0.004  ...             TRANGE_14  0.003
# 125             TRANGE_28  0.002  ...             TRANGE_28  0.003
# 126                  AD_5  0.018  ...                  AD_5  0.000
# 127                 AD_14  0.000  ...                 AD_14  0.003
# 128                 AD_28  0.006  ...                 AD_28  0.000
# 129               ADOSC_5  0.007  ...               ADOSC_5  0.000
# 130              ADOSC_14  0.000  ...              ADOSC_14  0.002
# 131              ADOSC_28  0.000  ...              ADOSC_28  0.005
# 132                 OBV_5  0.005  ...                 OBV_5  0.000
# 133                OBV_14  0.005  ...                OBV_14  0.000
# 134                OBV_28  0.000  ...                OBV_28  0.001
# 135       AROON_aroondown  0.000  ...       AROON_aroondown  0.000
# 136         AROON_aroonup  0.000  ...         AROON_aroonup  0.000
# 137             MACD_macd  0.010  ...             MACD_macd  0.002
# 138       MACD_macdsignal  0.017  ...       MACD_macdsignal  0.000
# 139         MACD_macdhist  0.000  ...         MACD_macdhist  0.000
# 140          MACDEXT_macd  0.014  ...          MACDEXT_macd  0.006
# 141    MACDEXT_macdsignal  0.009  ...    MACDEXT_macdsignal  0.007
# 142      MACDEXT_macdhist  0.000  ...      MACDEXT_macdhist  0.000
# 143          MACDFIX_macd  0.005  ...          MACDFIX_macd  0.000
# 144    MACDFIX_macdsignal  0.029  ...    MACDFIX_macdsignal  0.000
# 145      MACDFIX_macdhist  0.000  ...      MACDFIX_macdhist  0.000
# 146           STOCH_slowk  0.000  ...           STOCH_slowk  0.003
# 147           STOCH_slowd  0.000  ...           STOCH_slowd  0.007
# 148          STOCHF_fastk  0.010  ...          STOCHF_fastk  0.019
# 149          STOCHF_fastd  0.004  ...          STOCHF_fastd  0.005
# 150        STOCHRSI_fastk  0.000  ...        STOCHRSI_fastk  0.000
# 151        STOCHRSI_fastd  0.000  ...        STOCHRSI_fastd  0.006
# 152     HT_PHASOR_inphase  0.000  ...     HT_PHASOR_inphase  0.007
# 153  HT_PHASOR_quadrature  0.009  ...  HT_PHASOR_quadrature  0.005
# 154          HT_SINE_sine  0.011  ...          HT_SINE_sine  0.004
# 155      HT_SINE_leadsine  0.000  ...      HT_SINE_leadsine  0.004
# 156      BBANDS_upperband  0.013  ...      BBANDS_upperband  0.006
# 157     BBANDS_middleband  0.010  ...     BBANDS_middleband  0.020
# 158      BBANDS_lowerband  0.000  ...      BBANDS_lowerband  0.007
# 159             MAMA_mama  0.001  ...             MAMA_mama  0.000
# 160             MAMA_fama  0.008  ...             MAMA_fama  0.004
# 161                 Min10  0.010  ...                 Min10  0.003
# 162               Min1000  0.021  ...               Min1000  0.042
# 163            Min10_1300  0.003  ...            Min10_1300  0.003
# 164            Min10_1000  0.025  ...            Min10_1000  0.008
#
#                         0      1                     0      1  \
# 0              Cl/min_day  0.025            Cl/min_day  0.008
# 1              Cl/max_day  0.021            Cl/max_day  0.008
# 2         max_day-min_day  0.006       max_day-min_day  0.000
# 3                   ADX_5  0.003                 ADX_5  0.003
# 4                  ADX_14  0.000                ADX_14  0.004
# 5                  ADX_28  0.000                ADX_28  0.008
# 6                  ADXR_5  0.000                ADXR_5  0.002
# 7                 ADXR_14  0.004               ADXR_14  0.003
# 8                 ADXR_28  0.007               ADXR_28  0.002
# 9                   APO_5  0.004                 APO_5  0.011
# 10                 APO_14  0.004                APO_14  0.007
# 11                 APO_28  0.004                APO_28  0.000
# 12             AROONOSC_5  0.000            AROONOSC_5  0.000
# 13            AROONOSC_14  0.000           AROONOSC_14  0.000
# 14            AROONOSC_28  0.007           AROONOSC_28  0.003
# 15                  BOP_5  0.008                 BOP_5  0.003
# 16                 BOP_14  0.015                BOP_14  0.012
# 17                 BOP_28  0.007                BOP_28  0.010
# 18                  CCI_5  0.000                 CCI_5  0.004
# 19                 CCI_14  0.017                CCI_14  0.006
# 20                 CCI_28  0.000                CCI_28  0.007
# 21                  CMO_5  0.013                 CMO_5  0.007
# 22                 CMO_14  0.000                CMO_14  0.002
# 23                 CMO_28  0.018                CMO_28  0.004
# 24                   DX_5  0.000                  DX_5  0.000
# 25                  DX_14  0.008                 DX_14  0.005
# 26                  DX_28  0.002                 DX_28  0.006
# 27                  MFI_5  0.004                 MFI_5  0.003
# 28                 MFI_14  0.000                MFI_14  0.000
# 29                 MFI_28  0.003                MFI_28  0.011
# 30             MINUS_DI_5  0.004            MINUS_DI_5  0.012
# 31            MINUS_DI_14  0.003           MINUS_DI_14  0.000
# 32            MINUS_DI_28  0.003           MINUS_DI_28  0.003
# 33             MINUS_DM_5  0.000            MINUS_DM_5  0.003
# 34            MINUS_DM_14  0.004           MINUS_DM_14  0.003
# 35            MINUS_DM_28  0.000           MINUS_DM_28  0.007
# 36                  MOM_5  0.003                 MOM_5  0.007
# 37                 MOM_14  0.009                MOM_14  0.000
# 38                 MOM_28  0.010                MOM_28  0.006
# 39              PLUS_DI_5  0.004             PLUS_DI_5  0.014
# 40             PLUS_DI_14  0.009            PLUS_DI_14  0.004
# 41             PLUS_DI_28  0.000            PLUS_DI_28  0.002
# 42              PLUS_DM_5  0.003             PLUS_DM_5  0.003
# 43             PLUS_DM_14  0.008            PLUS_DM_14  0.014
# 44             PLUS_DM_28  0.009            PLUS_DM_28  0.006
# 45                  PPO_5  0.005                 PPO_5  0.014
# 46                 PPO_14  0.012                PPO_14  0.031
# 47                 PPO_28  0.011                PPO_28  0.003
# 48                  ROC_5  0.005                 ROC_5  0.008
# 49                 ROC_14  0.003                ROC_14  0.005
# 50                 ROC_28  0.011                ROC_28  0.011
# 51                 ROCP_5  0.011                ROCP_5  0.005
# 52                ROCP_14  0.000               ROCP_14  0.004
# 53                ROCP_28  0.006               ROCP_28  0.016
# 54                 ROCR_5  0.022                ROCR_5  0.014
# 55                ROCR_14  0.003               ROCR_14  0.000
# 56                ROCR_28  0.011               ROCR_28  0.016
# 57              ROCR100_5  0.021             ROCR100_5  0.012
# 58             ROCR100_14  0.005            ROCR100_14  0.004
# 59             ROCR100_28  0.014            ROCR100_28  0.014
# 60                  RSI_5  0.014                 RSI_5  0.011
# 61                 RSI_14  0.008                RSI_14  0.010
# 62                 RSI_28  0.020                RSI_28  0.000
# 63                 TRIX_5  0.000                TRIX_5  0.004
# 64                TRIX_14  0.003               TRIX_14  0.003
# 65                TRIX_28  0.000               TRIX_28  0.000
# 66               ULTOSC_5  0.004              ULTOSC_5  0.005
# 67              ULTOSC_14  0.007             ULTOSC_14  0.014
# 68              ULTOSC_28  0.002             ULTOSC_28  0.013
# 69                WILLR_5  0.011               WILLR_5  0.014
# 70               WILLR_14  0.008              WILLR_14  0.000
# 71               WILLR_28  0.015              WILLR_28  0.013
# 72          HT_DCPERIOD_5  0.006         HT_DCPERIOD_5  0.002
# 73         HT_DCPERIOD_14  0.002        HT_DCPERIOD_14  0.001
# 74         HT_DCPERIOD_28  0.006        HT_DCPERIOD_28  0.000
# 75           HT_DCPHASE_5  0.000          HT_DCPHASE_5  0.011
# 76          HT_DCPHASE_14  0.000         HT_DCPHASE_14  0.003
# 77          HT_DCPHASE_28  0.005         HT_DCPHASE_28  0.006
# 78         HT_TRENDMODE_5  0.000        HT_TRENDMODE_5  0.000
# 79        HT_TRENDMODE_14  0.000       HT_TRENDMODE_14  0.000
# 80        HT_TRENDMODE_28  0.000       HT_TRENDMODE_28  0.000
# 81                 DEMA_5  0.005                DEMA_5  0.002
# 82                DEMA_14  0.012               DEMA_14  0.021
# 83                DEMA_28  0.010               DEMA_28  0.000
# 84                  EMA_5  0.003                 EMA_5  0.008
# 85                 EMA_14  0.003                EMA_14  0.000
# 86                 EMA_28  0.015                EMA_28  0.003
# 87         HT_TRENDLINE_5  0.004        HT_TRENDLINE_5  0.000
# 88        HT_TRENDLINE_14  0.003       HT_TRENDLINE_14  0.000
# 89        HT_TRENDLINE_28  0.010       HT_TRENDLINE_28  0.000
# 90                 KAMA_5  0.014                KAMA_5  0.008
# 91                KAMA_14  0.009               KAMA_14  0.005
# 92                KAMA_28  0.004               KAMA_28  0.012
# 93                   MA_5  0.007                  MA_5  0.008
# 94                  MA_14  0.006                 MA_14  0.000
# 95                  MA_28  0.011                 MA_28  0.006
# 96             MIDPOINT_5  0.012            MIDPOINT_5  0.005
# 97            MIDPOINT_14  0.002           MIDPOINT_14  0.003
# 98            MIDPOINT_28  0.005           MIDPOINT_28  0.004
# 99             MIDPRICE_5  0.007            MIDPRICE_5  0.000
# 100           MIDPRICE_14  0.000           MIDPRICE_14  0.011
# 101           MIDPRICE_28  0.004           MIDPRICE_28  0.003
# 102                 SMA_5  0.009                 SMA_5  0.013
# 103                SMA_14  0.007                SMA_14  0.004
# 104                SMA_28  0.001                SMA_28  0.003
# 105                  T3_5  0.009                  T3_5  0.010
# 106                 T3_14  0.002                 T3_14  0.000
# 107                 T3_28  0.004                 T3_28  0.013
# 108                TEMA_5  0.007                TEMA_5  0.002
# 109               TEMA_14  0.006               TEMA_14  0.014
# 110               TEMA_28  0.007               TEMA_28  0.009
# 111               TRIMA_5  0.007               TRIMA_5  0.022
# 112              TRIMA_14  0.005              TRIMA_14  0.005
# 113              TRIMA_28  0.007              TRIMA_28  0.009
# 114                 WMA_5  0.013                 WMA_5  0.017
# 115                WMA_14  0.000                WMA_14  0.014
# 116                WMA_28  0.011                WMA_28  0.003
# 117                 ATR_5  0.007                 ATR_5  0.010
# 118                ATR_14  0.004                ATR_14  0.003
# 119                ATR_28  0.000                ATR_28  0.003
# 120                NATR_5  0.006                NATR_5  0.000
# 121               NATR_14  0.007               NATR_14  0.004
# 122               NATR_28  0.007               NATR_28  0.006
# 123              TRANGE_5  0.003              TRANGE_5  0.000
# 124             TRANGE_14  0.010             TRANGE_14  0.006
# 125             TRANGE_28  0.007             TRANGE_28  0.012
# 126                  AD_5  0.003                  AD_5  0.000
# 127                 AD_14  0.003                 AD_14  0.002
# 128                 AD_28  0.000                 AD_28  0.004
# 129               ADOSC_5  0.009               ADOSC_5  0.003
# 130              ADOSC_14  0.000              ADOSC_14  0.004
# 131              ADOSC_28  0.006              ADOSC_28  0.005
# 132                 OBV_5  0.002                 OBV_5  0.005
# 133                OBV_14  0.009                OBV_14  0.002
# 134                OBV_28  0.005                OBV_28  0.000
# 135       AROON_aroondown  0.000       AROON_aroondown  0.000
# 136         AROON_aroonup  0.000         AROON_aroonup  0.003
# 137             MACD_macd  0.000             MACD_macd  0.003
# 138       MACD_macdsignal  0.007       MACD_macdsignal  0.004
# 139         MACD_macdhist  0.015         MACD_macdhist  0.003
# 140          MACDEXT_macd  0.003          MACDEXT_macd  0.018
# 141    MACDEXT_macdsignal  0.002    MACDEXT_macdsignal  0.008
# 142      MACDEXT_macdhist  0.001      MACDEXT_macdhist  0.009
# 143          MACDFIX_macd  0.004          MACDFIX_macd  0.000
# 144    MACDFIX_macdsignal  0.004    MACDFIX_macdsignal  0.003
# 145      MACDFIX_macdhist  0.000      MACDFIX_macdhist  0.004
# 146           STOCH_slowk  0.010           STOCH_slowk  0.003
# 147           STOCH_slowd  0.008           STOCH_slowd  0.000
# 148          STOCHF_fastk  0.014          STOCHF_fastk  0.026
# 149          STOCHF_fastd  0.003          STOCHF_fastd  0.002
# 150        STOCHRSI_fastk  0.008        STOCHRSI_fastk  0.000
# 151        STOCHRSI_fastd  0.000        STOCHRSI_fastd  0.000
# 152     HT_PHASOR_inphase  0.004     HT_PHASOR_inphase  0.000
# 153  HT_PHASOR_quadrature  0.006  HT_PHASOR_quadrature  0.007
# 154          HT_SINE_sine  0.003          HT_SINE_sine  0.003
# 155      HT_SINE_leadsine  0.003      HT_SINE_leadsine  0.006
# 156      BBANDS_upperband  0.011      BBANDS_upperband  0.016
# 157     BBANDS_middleband  0.000     BBANDS_middleband  0.006
# 158      BBANDS_lowerband  0.003      BBANDS_lowerband  0.000
# 159             MAMA_mama  0.004             MAMA_mama  0.015
# 160             MAMA_fama  0.004             MAMA_fama  0.008
# 161                 Min10  0.000                 Min10  0.000
# 162               Min1000  0.041               Min1000  0.049
# 163            Min10_1300  0.006            Min10_1300  0.006
# 164            Min10_1000  0.003            Min10_1000  0.005
#
#                         0      1                     0      1
# 0              Cl/min_day  0.019            Cl/min_day  0.019
# 1              Cl/max_day  0.014            Cl/max_day  0.028
# 2         max_day-min_day  0.005       max_day-min_day  0.000
# 3                   ADX_5  0.000                 ADX_5  0.003
# 4                  ADX_14  0.010                ADX_14  0.003
# 5                  ADX_28  0.002                ADX_28  0.006
# 6                  ADXR_5  0.000                ADXR_5  0.005
# 7                 ADXR_14  0.005               ADXR_14  0.008
# 8                 ADXR_28  0.000               ADXR_28  0.000
# 9                   APO_5  0.003                 APO_5  0.002
# 10                 APO_14  0.012                APO_14  0.004
# 11                 APO_28  0.000                APO_28  0.003
# 12             AROONOSC_5  0.000            AROONOSC_5  0.000
# 13            AROONOSC_14  0.003           AROONOSC_14  0.000
# 14            AROONOSC_28  0.000           AROONOSC_28  0.000
# 15                  BOP_5  0.012                 BOP_5  0.007
# 16                 BOP_14  0.003                BOP_14  0.007
# 17                 BOP_28  0.008                BOP_28  0.000
# 18                  CCI_5  0.000                 CCI_5  0.010
# 19                 CCI_14  0.006                CCI_14  0.002
# 20                 CCI_28  0.015                CCI_28  0.017
# 21                  CMO_5  0.014                 CMO_5  0.014
# 22                 CMO_14  0.007                CMO_14  0.002
# 23                 CMO_28  0.009                CMO_28  0.000
# 24                   DX_5  0.008                  DX_5  0.003
# 25                  DX_14  0.000                 DX_14  0.005
# 26                  DX_28  0.008                 DX_28  0.006
# 27                  MFI_5  0.009                 MFI_5  0.008
# 28                 MFI_14  0.005                MFI_14  0.003
# 29                 MFI_28  0.000                MFI_28  0.003
# 30             MINUS_DI_5  0.007            MINUS_DI_5  0.004
# 31            MINUS_DI_14  0.010           MINUS_DI_14  0.009
# 32            MINUS_DI_28  0.002           MINUS_DI_28  0.002
# 33             MINUS_DM_5  0.005            MINUS_DM_5  0.013
# 34            MINUS_DM_14  0.006           MINUS_DM_14  0.005
# 35            MINUS_DM_28  0.010           MINUS_DM_28  0.003
# 36                  MOM_5  0.002                 MOM_5  0.010
# 37                 MOM_14  0.007                MOM_14  0.000
# 38                 MOM_28  0.008                MOM_28  0.004
# 39              PLUS_DI_5  0.002             PLUS_DI_5  0.006
# 40             PLUS_DI_14  0.011            PLUS_DI_14  0.008
# 41             PLUS_DI_28  0.000            PLUS_DI_28  0.003
# 42              PLUS_DM_5  0.011             PLUS_DM_5  0.026
# 43             PLUS_DM_14  0.014            PLUS_DM_14  0.009
# 44             PLUS_DM_28  0.009            PLUS_DM_28  0.004
# 45                  PPO_5  0.002                 PPO_5  0.010
# 46                 PPO_14  0.020                PPO_14  0.009
# 47                 PPO_28  0.008                PPO_28  0.000
# 48                  ROC_5  0.012                 ROC_5  0.014
# 49                 ROC_14  0.000                ROC_14  0.006
# 50                 ROC_28  0.013                ROC_28  0.023
# 51                 ROCP_5  0.012                ROCP_5  0.015
# 52                ROCP_14  0.000               ROCP_14  0.000
# 53                ROCP_28  0.011               ROCP_28  0.014
# 54                 ROCR_5  0.011                ROCR_5  0.016
# 55                ROCR_14  0.000               ROCR_14  0.000
# 56                ROCR_28  0.017               ROCR_28  0.019
# 57              ROCR100_5  0.004             ROCR100_5  0.011
# 58             ROCR100_14  0.005            ROCR100_14  0.002
# 59             ROCR100_28  0.014            ROCR100_28  0.000
# 60                  RSI_5  0.004                 RSI_5  0.007
# 61                 RSI_14  0.000                RSI_14  0.000
# 62                 RSI_28  0.003                RSI_28  0.000
# 63                 TRIX_5  0.004                TRIX_5  0.003
# 64                TRIX_14  0.002               TRIX_14  0.003
# 65                TRIX_28  0.005               TRIX_28  0.003
# 66               ULTOSC_5  0.002              ULTOSC_5  0.000
# 67              ULTOSC_14  0.005             ULTOSC_14  0.032
# 68              ULTOSC_28  0.008             ULTOSC_28  0.008
# 69                WILLR_5  0.011               WILLR_5  0.016
# 70               WILLR_14  0.010              WILLR_14  0.017
# 71               WILLR_28  0.000              WILLR_28  0.011
# 72          HT_DCPERIOD_5  0.002         HT_DCPERIOD_5  0.005
# 73         HT_DCPERIOD_14  0.000        HT_DCPERIOD_14  0.002
# 74         HT_DCPERIOD_28  0.000        HT_DCPERIOD_28  0.009
# 75           HT_DCPHASE_5  0.007          HT_DCPHASE_5  0.000
# 76          HT_DCPHASE_14  0.016         HT_DCPHASE_14  0.002
# 77          HT_DCPHASE_28  0.000         HT_DCPHASE_28  0.011
# 78         HT_TRENDMODE_5  0.000        HT_TRENDMODE_5  0.000
# 79        HT_TRENDMODE_14  0.000       HT_TRENDMODE_14  0.000
# 80        HT_TRENDMODE_28  0.000       HT_TRENDMODE_28  0.000
# 81                 DEMA_5  0.003                DEMA_5  0.002
# 82                DEMA_14  0.012               DEMA_14  0.002
# 83                DEMA_28  0.000               DEMA_28  0.006
# 84                  EMA_5  0.004                 EMA_5  0.012
# 85                 EMA_14  0.008                EMA_14  0.003
# 86                 EMA_28  0.007                EMA_28  0.000
# 87         HT_TRENDLINE_5  0.000        HT_TRENDLINE_5  0.000
# 88        HT_TRENDLINE_14  0.000       HT_TRENDLINE_14  0.003
# 89        HT_TRENDLINE_28  0.013       HT_TRENDLINE_28  0.000
# 90                 KAMA_5  0.008                KAMA_5  0.011
# 91                KAMA_14  0.000               KAMA_14  0.008
# 92                KAMA_28  0.007               KAMA_28  0.007
# 93                   MA_5  0.005                  MA_5  0.009
# 94                  MA_14  0.003                 MA_14  0.002
# 95                  MA_28  0.004                 MA_28  0.002
# 96             MIDPOINT_5  0.000            MIDPOINT_5  0.005
# 97            MIDPOINT_14  0.008           MIDPOINT_14  0.002
# 98            MIDPOINT_28  0.008           MIDPOINT_28  0.000
# 99             MIDPRICE_5  0.005            MIDPRICE_5  0.004
# 100           MIDPRICE_14  0.003           MIDPRICE_14  0.004
# 101           MIDPRICE_28  0.007           MIDPRICE_28  0.011
# 102                 SMA_5  0.003                 SMA_5  0.026
# 103                SMA_14  0.006                SMA_14  0.000
# 104                SMA_28  0.006                SMA_28  0.003
# 105                  T3_5  0.001                  T3_5  0.004
# 106                 T3_14  0.003                 T3_14  0.003
# 107                 T3_28  0.020                 T3_28  0.014
# 108                TEMA_5  0.000                TEMA_5  0.003
# 109               TEMA_14  0.026               TEMA_14  0.004
# 110               TEMA_28  0.000               TEMA_28  0.007
# 111               TRIMA_5  0.023               TRIMA_5  0.012
# 112              TRIMA_14  0.003              TRIMA_14  0.000
# 113              TRIMA_28  0.011              TRIMA_28  0.002
# 114                 WMA_5  0.000                 WMA_5  0.004
# 115                WMA_14  0.002                WMA_14  0.014
# 116                WMA_28  0.000                WMA_28  0.008
# 117                 ATR_5  0.000                 ATR_5  0.012
# 118                ATR_14  0.007                ATR_14  0.006
# 119                ATR_28  0.019                ATR_28  0.000
# 120                NATR_5  0.000                NATR_5  0.002
# 121               NATR_14  0.015               NATR_14  0.000
# 122               NATR_28  0.002               NATR_28  0.000
# 123              TRANGE_5  0.006              TRANGE_5  0.004
# 124             TRANGE_14  0.007             TRANGE_14  0.011
# 125             TRANGE_28  0.002             TRANGE_28  0.008
# 126                  AD_5  0.000                  AD_5  0.000
# 127                 AD_14  0.000                 AD_14  0.000
# 128                 AD_28  0.000                 AD_28  0.000
# 129               ADOSC_5  0.010               ADOSC_5  0.001
# 130              ADOSC_14  0.003              ADOSC_14  0.003
# 131              ADOSC_28  0.004              ADOSC_28  0.012
# 132                 OBV_5  0.009                 OBV_5  0.006
# 133                OBV_14  0.004                OBV_14  0.000
# 134                OBV_28  0.005                OBV_28  0.000
# 135       AROON_aroondown  0.000       AROON_aroondown  0.003
# 136         AROON_aroonup  0.000         AROON_aroonup  0.002
# 137             MACD_macd  0.003             MACD_macd  0.000
# 138       MACD_macdsignal  0.011       MACD_macdsignal  0.006
# 139         MACD_macdhist  0.005         MACD_macdhist  0.011
# 140          MACDEXT_macd  0.025          MACDEXT_macd  0.000
# 141    MACDEXT_macdsignal  0.009    MACDEXT_macdsignal  0.000
# 142      MACDEXT_macdhist  0.000      MACDEXT_macdhist  0.004
# 143          MACDFIX_macd  0.000          MACDFIX_macd  0.000
# 144    MACDFIX_macdsignal  0.004    MACDFIX_macdsignal  0.000
# 145      MACDFIX_macdhist  0.002      MACDFIX_macdhist  0.005
# 146           STOCH_slowk  0.004           STOCH_slowk  0.014
# 147           STOCH_slowd  0.003           STOCH_slowd  0.022
# 148          STOCHF_fastk  0.022          STOCHF_fastk  0.018
# 149          STOCHF_fastd  0.003          STOCHF_fastd  0.002
# 150        STOCHRSI_fastk  0.004        STOCHRSI_fastk  0.002
# 151        STOCHRSI_fastd  0.000        STOCHRSI_fastd  0.012
# 152     HT_PHASOR_inphase  0.003     HT_PHASOR_inphase  0.000
# 153  HT_PHASOR_quadrature  0.007  HT_PHASOR_quadrature  0.002
# 154          HT_SINE_sine  0.003          HT_SINE_sine  0.000
# 155      HT_SINE_leadsine  0.003      HT_SINE_leadsine  0.003
# 156      BBANDS_upperband  0.014      BBANDS_upperband  0.004
# 157     BBANDS_middleband  0.010     BBANDS_middleband  0.010
# 158      BBANDS_lowerband  0.006      BBANDS_lowerband  0.013
# 159             MAMA_mama  0.012             MAMA_mama  0.008
# 160             MAMA_fama  0.008             MAMA_fama  0.011
# 161                 Min10  0.004                 Min10  0.012
# 162               Min1000  0.042               Min1000  0.021
# 163            Min10_1300  0.003            Min10_1300  0.009
# 164            Min10_1000  0.005            Min10_1000  0.000
#
# [165 rows x 540 columns]

# %%
#прогнозы
def result_(varP, varM):
    tablep = pd.pivot_table(
    matrix_year[(matrix_year['2proba']>=varP) &(matrix_year[column] >200)],                      
            margins=True, index=all, values = ['Target_','Profit_carrent'],
            aggfunc=['count', 'mean']).round(2)
    
    tablem = pd.pivot_table(
    matrix_year[(matrix_year['1proba']>varM) &(matrix_year[column] >200)],                      
            margins=True, index=all, values = ['Target_','Profit_carrent'],
            aggfunc=['count', 'mean']).round(2)
    table = pd.concat([tablep, tablem], axis=1)
#    table.columns = ['Profit%_c','Count','Profit%','Profit+-']
#    table.pop('Profit%_c')
    return table
